# %%
import engine
from engine import Engine
from config import Config
import importlib
importlib.reload(engine)
e = Engine("setup.yaml")
# Out:
# Loaded data from setup.yaml

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
e.fixed_steps_simulation(10000)
# Out:
# time: 0.0
# iterations: 1
# dist: 1.9002515966397715
#  id:atom1, pos:[1.511083 2.552912], vel:[ 0.00256525 -0.00012952]
#  id:atom2, pos:[3.408917 2.457088], vel:[-0.00256525  0.00012952]
# E -0.08097011043770383
#
# time: 0.02
# iterations: 2
# dist: 1.9000461153523196
#  id:atom1, pos:[1.51118561 2.55290682], vel:[ 0.00769761 -0.00038866]
#  id:atom2, pos:[3.40881439 2.45709318], vel:[-0.00769761  0.00038866]
# E -0.08097010082005947
#
# time: 0.04
# iterations: 3
# dist: 1.8996350030948808
#  id:atom1, pos:[1.5113909  2.55289645], vel:[ 0.01283559 -0.00064808]
#  id:atom2, pos:[3.4086091  2.45710355], vel:[-0.01283559  0.00064808]
# E -0.08097008151771327
#
# time: 0.06
# iterations: 4
# dist: 1.8990179600293475
#  id:atom1, pos:[1.51169903 2.5528809 ], vel:[ 0.01798294 -0.00090798]
#  id:atom2, pos:[3.40830097 2.4571191 ], vel:[-0.01798294  0.00090798]
# E -0.08097005239575748
#
# time: 0.08
# iterations: 5
# dist: 1.8981945352127083
#  id:atom1, pos:[1.51211022 2.55286013], vel:[ 0.02314345 -0.00116854]
#  id:atom2, pos:[3.40788978 2.45713987], vel:[-0.02314345  0.00116854]
# E -0.08097001324983423
#
# time: 0.1
# iterations: 6
# dist: 1.8971641251648645
#  id:atom1, pos:[1.51262477 2.55283415], vel:[ 0.02832096 -0.00142996]
#  id:atom2, pos:[3.40737523 2.45716585], vel:[-0.02832096  0.00142996]
# E -0.08096996380369972
#
# time: 0.12000000000000001
# iterations: 7
# dist: 1.895925971943666
#  id:atom1, pos:[1.51324306 2.55280294], vel:[ 0.03351936 -0.00169243]
#  id:atom2, pos:[3.40675694 2.45719706], vel:[-0.03351936  0.00169243]
# E -0.08096990370590817
#
# time: 0.14
# iterations: 8
# dist: 1.8944791607137481
#  id:atom1, pos:[1.51396555 2.55276646], vel:[ 0.03874259 -0.00195616]
#  id:atom2, pos:[3.40603445 2.45723354], vel:[-0.03874259  0.00195616]
# E -0.08096983252555384
#
# time: 0.16
# iterations: 9
# dist: 1.8928226167920834
#  id:atom1, pos:[1.51479276 2.55272469], vel:[ 0.04399469 -0.00222135]
#  id:atom2, pos:[3.40520724 2.45727531], vel:[-0.04399469  0.00222135]
# E -0.08096974974699345
#
# time: 0.18
# iterations: 10
# dist: 1.8909551021493145
#  id:atom1, pos:[1.51572533 2.5526776 ], vel:[ 0.04927979 -0.0024882 ]
#  id:atom2, pos:[3.40427467 2.4573224 ], vel:[-0.04927979  0.0024882 ]
# E -0.08096965476344876
#
# time: 0.19999999999999998
# iterations: 11
# dist: 1.8888752113418106
#  id:atom1, pos:[1.51676396 2.55262516], vel:[ 0.05460214 -0.00275693]
#  id:atom2, pos:[3.40323604 2.45737484], vel:[-0.05460214  0.00275693]
# E -0.08096954686936741
#
# time: 0.21999999999999997
# iterations: 12
# dist: 1.8865813668449576
#  id:atom1, pos:[1.51790942 2.55256733], vel:[ 0.05996608 -0.00302776]
#  id:atom2, pos:[3.40209058 2.45743267], vel:[-0.05996608  0.00302776]
# E -0.08096942525139339
#
# time: 0.23999999999999996
# iterations: 13
# dist: 1.884071813753393
#  id:atom1, pos:[1.5191626  2.55250405], vel:[ 0.06537613 -0.00330092]
#  id:atom2, pos:[3.4008374  2.45749595], vel:[-0.06537613  0.00330092]
# E -0.08096928897776998
#
# time: 0.25999999999999995
# iterations: 14
# dist: 1.881344613808659
#  id:atom1, pos:[1.52052446 2.55243529], vel:[ 0.07083695 -0.00357665]
#  id:atom2, pos:[3.39947554 2.45756471], vel:[-0.07083695  0.00357665]
# E -0.08096913698595912
#
# time: 0.27999999999999997
# iterations: 15
# dist: 1.8783976387089938
#  id:atom1, pos:[1.52199608 2.55236099], vel:[ 0.07635338 -0.00385518]
#  id:atom2, pos:[3.39800392 2.45763901], vel:[-0.07635338  0.00385518]
# E -0.08096896806822375
#
# time: 0.3
# iterations: 16
# dist: 1.8752285626496172
#  id:atom1, pos:[1.5235786  2.55228108], vel:[ 0.08193044 -0.00413677]
#  id:atom2, pos:[3.3964214  2.45771892], vel:[-0.08193044  0.00413677]
# E -0.0809687808548675
#
# time: 0.32
# iterations: 17
# dist: 1.8718348540348255
#  id:atom1, pos:[1.52527329 2.55219551], vel:[ 0.0875734  -0.00442169]
#  id:atom2, pos:[3.39472671 2.45780449], vel:[-0.0875734   0.00442169]
# E -0.08096857379477009
#
# time: 0.34
# iterations: 18
# dist: 1.8682137662953369
#  id:atom1, pos:[1.52708154 2.55210421], vel:[ 0.09328774 -0.00471021]
#  id:atom2, pos:[3.39291846 2.45789579], vel:[-0.09328774  0.00471021]
# E -0.0809683451327847
#
# time: 0.36000000000000004
# iterations: 19
# dist: 1.8643623277355177
#  id:atom1, pos:[1.5290048  2.55200711], vel:[ 0.09907924 -0.00500263]
#  id:atom2, pos:[3.3909952  2.45799289], vel:[-0.09907924  0.00500263]
# E -0.08096809288348467
#
# time: 0.38000000000000006
# iterations: 20
# dist: 1.86027733032523
#  id:atom1, pos:[1.5310447  2.55190411], vel:[ 0.10495393 -0.00529925]
#  id:atom2, pos:[3.3889553  2.45809589], vel:[-0.10495393  0.00529925]
# E -0.08096781480064127
#
# time: 0.4000000000000001
# iterations: 21
# dist: 1.8559553173398655
#  id:atom1, pos:[1.53320296 2.55179514], vel:[ 0.11091821 -0.0056004 ]
#  id:atom2, pos:[3.38679704 2.45820486], vel:[-0.11091821  0.0056004 ]
# E -0.08096750834169836
#
# time: 0.4200000000000001
# iterations: 22
# dist: 1.8513925697394893
#  id:atom1, pos:[1.53548143 2.55168009], vel:[ 0.11697881 -0.00590641]
#  id:atom2, pos:[3.38451857 2.45831991], vel:[-0.11697881  0.00590641]
# E -0.08096717062636066
#
# time: 0.4400000000000001
# iterations: 23
# dist: 1.8465850911636874
#  id:atom1, pos:[1.53788211 2.55155888], vel:[ 0.12314286 -0.00621764]
#  id:atom2, pos:[3.38211789 2.45844112], vel:[-0.12314286  0.00621764]
# E -0.08096679838823534
#
# time: 0.46000000000000013
# iterations: 24
# dist: 1.841528591402351
#  id:atom1, pos:[1.54040715 2.55143139], vel:[ 0.12941793 -0.00653447]
#  id:atom2, pos:[3.37959285 2.45856861], vel:[-0.12941793  0.00653447]
# E -0.08096638791825139
#
# time: 0.48000000000000015
# iterations: 25
# dist: 1.8362184681840108
#  id:atom1, pos:[1.54305883 2.5512975 ], vel:[ 0.13581205 -0.00685732]
#  id:atom2, pos:[3.37694117 2.4587025 ], vel:[-0.13581205  0.00685732]
# E -0.08096593499831353
#
# time: 0.5000000000000001
# iterations: 26
# dist: 1.8306497871019585
#  id:atom1, pos:[1.54583963 2.55115709], vel:[ 0.14233379 -0.00718661]
#  id:atom2, pos:[3.37416037 2.45884291], vel:[-0.14233379  0.00718661]
# E -0.08096543482332723
#
# time: 0.5200000000000001
# iterations: 27
# dist: 1.8248172594739016
#  id:atom1, pos:[1.54875218 2.55101004], vel:[ 0.14899232 -0.00752281]
#  id:atom2, pos:[3.37124782 2.45898996], vel:[-0.14899232  0.00752281]
# E -0.08096488190932725
#
# time: 0.5400000000000001
# iterations: 28
# dist: 1.8187152179026906
#  id:atom1, pos:[1.55179932 2.55085618], vel:[ 0.15579741 -0.00786641]
#  id:atom2, pos:[3.36820068 2.45914382], vel:[-0.15579741  0.00786641]
# E -0.0809642699849517
#
# time: 0.5600000000000002
# iterations: 29
# dist: 1.8123375892731055
#  id:atom1, pos:[1.55498408 2.55069538], vel:[ 0.16275958 -0.00821793]
#  id:atom2, pos:[3.36501592 2.45930462], vel:[-0.16275958  0.00821793]
# E -0.08096359186289416
#
# time: 0.5800000000000002
# iterations: 30
# dist: 1.805677864882061
#  id:atom1, pos:[1.55830971 2.55052746], vel:[ 0.16989011 -0.00857796]
#  id:atom2, pos:[3.36169029 2.45947254], vel:[-0.16989011  0.00857796]
# E -0.08096283928720475
#
# time: 0.6000000000000002
# iterations: 31
# dist: 1.7987290673559297
#  id:atom1, pos:[1.56177968 2.55035226], vel:[ 0.17720116 -0.00894711]
#  id:atom2, pos:[3.35822032 2.45964774], vel:[-0.17720116  0.00894711]
# E -0.08096200275137086
#
# time: 0.6200000000000002
# iterations: 32
# dist: 1.7914837139579443
#  id:atom1, pos:[1.56539775 2.55016958], vel:[ 0.18470585 -0.00932603]
#  id:atom2, pos:[3.35460225 2.45983042], vel:[-0.18470585  0.00932603]
# E -0.08096107128092496
#
# time: 0.6400000000000002
# iterations: 33
# dist: 1.78393377582951
#  id:atom1, pos:[1.56916792 2.54997922], vel:[ 0.1924184  -0.00971544]
#  id:atom2, pos:[3.35083208 2.46002078], vel:[-0.1924184   0.00971544]
# E -0.08096003217284822
#
# time: 0.6600000000000003
# iterations: 34
# dist: 1.7760706326401825
#  id:atom1, pos:[1.57309449 2.54978096], vel:[ 0.2003542  -0.01011613]
#  id:atom2, pos:[3.34690551 2.46021904], vel:[-0.2003542   0.01011613]
# E -0.08095887068217965
#
# time: 0.6800000000000003
# iterations: 35
# dist: 1.7678850220401852
#  id:atom1, pos:[1.57718209 2.54957457], vel:[ 0.20852998 -0.01052894]
#  id:atom2, pos:[3.34281791 2.46042543], vel:[-0.20852998  0.01052894]
# E -0.08095756964389589
#
# time: 0.7000000000000003
# iterations: 36
# dist: 1.759366983214409
#  id:atom1, pos:[1.58143569 2.54935981], vel:[ 0.21696397 -0.01095478]
#  id:atom2, pos:[3.33856431 2.46064019], vel:[-0.21696397  0.01095478]
# E -0.08095610901516445
#
# time: 0.7200000000000003
# iterations: 37
# dist: 1.7505057937251847
#  id:atom1, pos:[1.58586064 2.54913638], vel:[ 0.22567607 -0.01139467]
#  id:atom2, pos:[3.33413936 2.46086362], vel:[-0.22567607  0.01139467]
# E -0.08095446531931996
#
# time: 0.7400000000000003
# iterations: 38
# dist: 1.7412898986994825
#  id:atom1, pos:[1.59046273 2.54890402], vel:[ 0.23468807 -0.01184969]
#  id:atom2, pos:[3.32953727 2.46109598], vel:[-0.23468807  0.01184969]
# E -0.08095261096815731
#
# time: 0.7600000000000003
# iterations: 39
# dist: 1.7317068312607478
#  id:atom1, pos:[1.59524817 2.5486624 ], vel:[ 0.24402384 -0.01232107]
#  id:atom2, pos:[3.32475183 2.4613376 ], vel:[-0.24402384  0.01232107]
# E -0.0809505134330818
#
# time: 0.7800000000000004
# iterations: 40
# dist: 1.7217431229216504
#  id:atom1, pos:[1.60022368 2.54841118], vel:[ 0.25370967 -0.01281012]
#  id:atom2, pos:[3.31977632 2.46158882], vel:[-0.25370967  0.01281012]
# E -0.08094813422798637
#
# time: 0.8000000000000004
# iterations: 41
# dist: 1.7113842024361325
#  id:atom1, pos:[1.60539655 2.54814999], vel:[ 0.2637745 -0.0133183]
#  id:atom2, pos:[3.31460345 2.46185001], vel:[-0.2637745  0.0133183]
# E -0.08094542765696498
#
# time: 0.8200000000000004
# iterations: 42
# dist: 1.7006142813507197
#  id:atom1, pos:[1.61077466 2.54787844], vel:[ 0.27425037 -0.01384724]
#  id:atom2, pos:[3.30922534 2.46212156], vel:[-0.27425037  0.01384724]
# E -0.08094233926763789
#
# time: 0.8400000000000004
# iterations: 43
# dist: 1.6894162241885156
#  id:atom1, pos:[1.61636657 2.5475961 ], vel:[ 0.28517273 -0.01439873]
#  id:atom2, pos:[3.30363343 2.4624039 ], vel:[-0.28517273  0.01439873]
# E -0.0809388039353178
#
# time: 0.8600000000000004
# iterations: 44
# dist: 1.6777714008357871
#  id:atom1, pos:[1.62218157 2.54730249], vel:[ 0.29658102 -0.01497474]
#  id:atom2, pos:[3.29781843 2.46269751], vel:[-0.29658102  0.01497474]
# E -0.08093474348385592
#
# time: 0.8800000000000004
# iterations: 45
# dist: 1.6656595182707523
#  id:atom1, pos:[1.62822981 2.54699711], vel:[ 0.30851914 -0.01557752]
#  id:atom2, pos:[3.29177019 2.46300289], vel:[-0.30851914  0.01557752]
# E -0.08093006372517178
#
# time: 0.9000000000000005
# iterations: 46
# dist: 1.6530584282664893
#  id:atom1, pos:[1.63452234 2.54667939], vel:[ 0.32103618 -0.01620952]
#  id:atom2, pos:[3.28547766 2.46332061], vel:[-0.32103618  0.01620952]
# E -0.0809246507709189
#
# time: 0.9200000000000005
# iterations: 47
# dist: 1.6399439071043722
#  id:atom1, pos:[1.64107126 2.54634873], vel:[ 0.33418711 -0.01687352]
#  id:atom2, pos:[3.27892874 2.46365127], vel:[-0.33418711  0.01687352]
# E -0.08091836643702531
#
# time: 0.9400000000000005
# iterations: 48
# dist: 1.6262894026425179
#  id:atom1, pos:[1.64788982 2.54600445], vel:[ 0.3480337  -0.01757265]
#  id:atom2, pos:[3.27211018 2.46399555], vel:[-0.3480337   0.01757265]
# E -0.08091104252743181
#
# time: 0.9600000000000005
# iterations: 49
# dist: 1.6120657432920642
#  id:atom1, pos:[1.6549926  2.54564583], vel:[ 0.36264554 -0.01831042]
#  id:atom2, pos:[3.2650074  2.46435417], vel:[-0.36264554  0.01831042]
# E -0.08090247375375179
#
# time: 0.9800000000000005
# iterations: 50
# dist: 1.597240802570891
#  id:atom1, pos:[1.66239564 2.54527204], vel:[ 0.37810124 -0.0190908 ]
#  id:atom2, pos:[3.25760436 2.46472796], vel:[-0.37810124  0.0190908 ]
# E -0.08089240903756112
#
# time: 1.0000000000000004
# iterations: 51
# dist: 1.5817791119606555
#  id:atom1, pos:[1.67011665 2.54488219], vel:[ 0.39448983 -0.01991828]
#  id:atom2, pos:[3.24988335 2.46511781], vel:[-0.39448983  0.01991828]
# E -0.08088054098308983
#
# time: 1.0200000000000005
# iterations: 52
# dist: 1.5656414138635961
#  id:atom1, pos:[1.67817524 2.54447531], vel:[ 0.41191235 -0.02079797]
#  id:atom2, pos:[3.24182476 2.46552469], vel:[-0.41191235  0.02079797]
# E -0.08086649346482705
#
# time: 1.0400000000000005
# iterations: 53
# dist: 1.5487841456959686
#  id:atom1, pos:[1.68659315 2.54405027], vel:[ 0.43048372 -0.02173566]
#  id:atom2, pos:[3.23340685 2.46594973], vel:[-0.43048372  0.02173566]
# E -0.08084980767790315
#
# time: 1.0600000000000005
# iterations: 54
# dist: 1.5311588458693897
#  id:atom1, pos:[1.69539459 2.54360588], vel:[ 0.45033474 -0.02273796]
#  id:atom2, pos:[3.22460541 2.46639412], vel:[-0.45033474  0.02273796]
# E -0.08082992791226021
#
# time: 1.0800000000000005
# iterations: 55
# dist: 1.5127114731748779
#  id:atom1, pos:[1.70460654 2.54314076], vel:[ 0.47161437 -0.0238124 ]
#  id:atom2, pos:[3.21539346 2.46685924], vel:[-0.47161437  0.0238124 ]
# E -0.08080619026448452
#
# time: 1.1000000000000005
# iterations: 56
# dist: 1.4933816339681703
#  id:atom1, pos:[1.71425916 2.54265338], vel:[ 0.49449201 -0.02496752]
#  id:atom2, pos:[3.20574084 2.46734662], vel:[-0.49449201  0.02496752]
# E -0.08077782156591423
#
# time: 1.1200000000000006
# iterations: 57
# dist: 1.47310171854326
#  id:atom1, pos:[1.72438622 2.54214206], vel:[ 0.51915955 -0.02621301]
#  id:atom2, pos:[3.19561378 2.46785794], vel:[-0.51915955  0.02621301]
# E -0.08074396416943197
#
# time: 1.1400000000000006
# iterations: 58
# dist: 1.4517959628542845
#  id:atom1, pos:[1.73502554 2.54160486], vel:[ 0.54583265 -0.02755977]
#  id:atom2, pos:[3.18497446 2.46839514], vel:[-0.54583265  0.02755977]
# E -0.08070375940811625
#
# time: 1.1600000000000006
# iterations: 59
# dist: 1.4293794811718337
#  id:atom1, pos:[1.74621952 2.54103966], vel:[ 0.57475022 -0.02901985]
#  id:atom2, pos:[3.17378048 2.46896034], vel:[-0.57475022  0.02901985]
# E -0.08065655790981424
#
# time: 1.1800000000000006
# iterations: 60
# dist: 1.4057573722794352
#  id:atom1, pos:[1.75801555 2.54044407], vel:[ 0.60616994 -0.03060627]
#  id:atom2, pos:[3.16198445 2.46955593], vel:[-0.60616994  0.03060627]
# E -0.08060239829590027
#
# time: 1.2000000000000006
# iterations: 61
# dist: 1.380824111116743
#  id:atom1, pos:[1.77046632 2.53981541], vel:[ 0.64035583 -0.03233236]
#  id:atom2, pos:[3.14953368 2.47018459], vel:[-0.64035583  0.03233236]
# E -0.08054304902000342
#
# time: 1.2200000000000006
# iterations: 62
# dist: 1.3544636471197278
#  id:atom1, pos:[1.78362979 2.53915077], vel:[ 0.67755036 -0.03421036]
#  id:atom2, pos:[3.13637021 2.47084923], vel:[-0.67755036  0.03421036]
# E -0.08048422995269583
#
# time: 1.2400000000000007
# iterations: 63
# dist: 1.326551033657438
#  id:atom1, pos:[1.79756834 2.538447  ], vel:[ 0.7179161  -0.03624848]
#  id:atom2, pos:[3.12243166 2.471553  ], vel:[-0.7179161   0.03624848]
# E -0.08044030526284596
#
# time: 1.2600000000000007
# iterations: 64
# dist: 1.2969571964507318
#  id:atom1, pos:[1.81234643 2.53770083], vel:[ 0.76141813 -0.03844495]
#  id:atom2, pos:[3.10765357 2.47229917], vel:[-0.76141813  0.03844495]
# E -0.08044412857406136
#
# time: 1.2800000000000007
# iterations: 65
# dist: 1.265559987013594
#  id:atom1, pos:[1.82802506 2.5369092 ], vel:[ 0.80758982 -0.04077621]
#  id:atom2, pos:[3.09197494 2.4730908 ], vel:[-0.80758982  0.04077621]
# E -0.08056741610604201
#
# time: 1.3000000000000007
# iterations: 66
# dist: 1.2322677093917636
#  id:atom1, pos:[1.84465002 2.53606979], vel:[ 0.85506917 -0.04317351]
#  id:atom2, pos:[3.07534998 2.47393021], vel:[-0.85506917  0.04317351]
# E -0.08096137898715416
#
# time: 1.3200000000000007
# iterations: 67
# dist: 1.1970673131998335
#  id:atom1, pos:[1.86222783 2.53518226], vel:[ 0.9006866  -0.04547679]
#  id:atom2, pos:[3.05777217 2.47481774], vel:[-0.9006866   0.04547679]
# E -0.0819299356017974
#
# time: 1.3400000000000007
# iterations: 68
# dist: 1.160120992668887
#  id:atom1, pos:[1.88067749 2.53425071], vel:[ 0.9377063  -0.04734596]
#  id:atom2, pos:[3.03932251 2.47574929], vel:[-0.9377063   0.04734596]
# E -0.08402389163346324
#
# time: 1.3600000000000008
# iterations: 69
# dist: 1.121955248074727
#  id:atom1, pos:[1.89973608 2.53328842], vel:[ 0.95263908 -0.04809993]
#  id:atom2, pos:[3.02026392 2.47671158], vel:[-0.95263908  0.04809993]
# E -0.08798303697734355
#
# time: 1.3800000000000008
# iterations: 70
# dist: 1.0838127830781934
#  id:atom1, pos:[1.91878305 2.53232672], vel:[ 0.92042297 -0.0464733 ]
#  id:atom2, pos:[3.00121695 2.47767328], vel:[-0.92042297  0.0464733 ]
# E -0.09374533716332256
#
# time: 1.4000000000000008
# iterations: 71
# dist: 1.048227610326588
#  id:atom1, pos:[1.936553   2.53142949], vel:[ 0.8009948  -0.04044322]
#  id:atom2, pos:[2.983447   2.47857051], vel:[-0.8009948   0.04044322]
# E -0.0969028435253847
#
# time: 1.4200000000000008
# iterations: 72
# dist: 1.0196515699590172
#  id:atom1, pos:[1.95082284 2.53070899], vel:[ 0.55042723 -0.02779176]
#  id:atom2, pos:[2.96917716 2.47929101], vel:[-0.55042723  0.02779176]
# E -0.086326699831141
#
# time: 1.4400000000000008
# iterations: 73
# dist: 1.0041373380683605
#  id:atom1, pos:[1.95857009 2.53031782], vel:[ 0.16589187 -0.00837609]
#  id:atom2, pos:[2.96142991 2.47968218], vel:[-0.16589187  0.00837609]
# E -0.06571407583585868
#
# time: 1.4600000000000009
# iterations: 74
# dist: 1.0063633143261341
#  id:atom1, pos:[1.95745852 2.53037394], vel:[-0.26773845  0.01351845]
#  id:atom2, pos:[2.96254148 2.47962606], vel:[ 0.26773845 -0.01351845]
# E -0.06975549841604438
#
# time: 1.4800000000000009
# iterations: 75
# dist: 1.025583698905233
#  id:atom1, pos:[1.94786055 2.53085856], vel:[-0.62424804  0.03151906]
#  id:atom2, pos:[2.97213945 2.47914144], vel:[ 0.62424804 -0.03151906]
# E -0.0905979076282748
#
# time: 1.5000000000000009
# iterations: 76
# dist: 1.0563667742279153
#  id:atom1, pos:[1.93248859 2.53163471], vel:[-0.8403251   0.04242906]
#  id:atom2, pos:[2.98751141 2.47836529], vel:[ 0.8403251  -0.04242906]
# E -0.09692255177386555
#
# time: 1.520000000000001
# iterations: 77
# dist: 1.0928953442766405
#  id:atom1, pos:[1.91424755 2.53255572], vel:[-0.93440964  0.04717951]
#  id:atom2, pos:[3.00575245 2.47744428], vel:[ 0.93440964 -0.04717951]
# E -0.09230490784565193
#
# time: 1.540000000000001
# iterations: 78
# dist: 1.1312147705381825
#  id:atom1, pos:[1.89511221 2.53352189], vel:[-0.95216221  0.04807585]
#  id:atom2, pos:[3.02488779 2.47647811], vel:[ 0.95216221 -0.04807585]
# E -0.08682754733070985
#
# time: 1.560000000000001
# iterations: 79
# dist: 1.169165355285032
#  id:atom1, pos:[1.87616106 2.53447875], vel:[-0.93014185  0.04696402]
#  id:atom2, pos:[3.04383894 2.47552125], vel:[ 0.93014185 -0.04696402]
# E -0.08337660680400116
#
# time: 1.580000000000001
# iterations: 80
# dist: 1.205720908877012
#  id:atom1, pos:[1.85790654 2.53540045], vel:[-0.89014139  0.04494435]
#  id:atom2, pos:[3.06209346 2.47459955], vel:[ 0.89014139 -0.04494435]
# E -0.08161932223364154
#
# time: 1.600000000000001
# iterations: 81
# dist: 1.2404673801828383
#  id:atom1, pos:[1.8405554  2.53627653], vel:[-0.84363428  0.04259614]
#  id:atom2, pos:[3.0794446  2.47372347], vel:[ 0.84363428 -0.04259614]
# E -0.0808289094738901
#
# time: 1.620000000000001
# iterations: 82
# dist: 1.2732976260949662
#  id:atom1, pos:[1.82416116 2.53710429], vel:[-0.79626976  0.04020465]
#  id:atom2, pos:[3.09583884 2.47289571], vel:[ 0.79626976 -0.04020465]
# E -0.08052063549890864
#
# time: 1.640000000000001
# iterations: 83
# dist: 1.3042501083475377
#  id:atom1, pos:[1.80870461 2.53788471], vel:[-0.75066159  0.03790184]
#  id:atom2, pos:[3.11129539 2.47211529], vel:[ 0.75066159 -0.03790184]
# E -0.08043602459590948
#
# time: 1.660000000000001
# iterations: 84
# dist: 1.3334270530248686
#  id:atom1, pos:[1.7941347  2.53862037], vel:[-0.70789455  0.03574248]
#  id:atom2, pos:[3.1258653  2.47137963], vel:[ 0.70789455 -0.03574248]
# E -0.08044831564419597
#
# time: 1.680000000000001
# iterations: 85
# dist: 1.3609538134755796
#  id:atom1, pos:[1.78038883 2.53931441], vel:[-0.66830012  0.0337433 ]
#  id:atom2, pos:[3.13961117 2.47068559], vel:[ 0.66830012 -0.0337433 ]
# E -0.08049790013007319
#
# time: 1.700000000000001
# iterations: 86
# dist: 1.386959169213751
#  id:atom1, pos:[1.7674027 2.5399701], vel:[-0.63184997  0.03190289]
#  id:atom2, pos:[3.1525973 2.4700299], vel:[ 0.63184997 -0.03190289]
# E -0.08055772120687305
#
# time: 1.720000000000001
# iterations: 87
# dist: 1.4115662029182405
#  id:atom1, pos:[1.75511483 2.54059053], vel:[-0.59835441  0.03021166]
#  id:atom2, pos:[3.16488517 2.46940947], vel:[ 0.59835441 -0.03021166]
# E -0.08061613998213718
#
# time: 1.740000000000001
# iterations: 88
# dist: 1.4348885004140572
#  id:atom1, pos:[1.74346852 2.54117857], vel:[-0.56756195  0.02865691]
#  id:atom2, pos:[3.17653148 2.46882143], vel:[ 0.56756195 -0.02865691]
# E -0.08066869375516467
#
# time: 1.7600000000000011
# iterations: 89
# dist: 1.4570289987899254
#  id:atom1, pos:[1.73241235 2.54173681], vel:[-0.53920829  0.0272253 ]
#  id:atom2, pos:[3.18758765 2.46826319], vel:[ 0.53920829 -0.0272253 ]
# E -0.08071417477831055
#
# time: 1.7800000000000011
# iterations: 90
# dist: 1.4780801140311648
#  id:atom1, pos:[1.72190019 2.54226758], vel:[-0.51303955  0.02590401]
#  id:atom2, pos:[3.19809981 2.46773242], vel:[ 0.51303955 -0.02590401]
# E -0.08075277718399654
#
# time: 1.8000000000000012
# iterations: 91
# dist: 1.4981244464724663
#  id:atom1, pos:[1.71189077 2.54277297], vel:[-0.48882221  0.02468124]
#  id:atom2, pos:[3.20810923 2.46722703], vel:[ 0.48882221 -0.02468124]
# E -0.08078523104081414
#
# time: 1.8200000000000012
# iterations: 92
# dist: 1.517235706371773
#  id:atom1, pos:[1.7023473  2.54325483], vel:[-0.46634636  0.02354641]
#  id:atom2, pos:[3.2176527  2.46674517], vel:[ 0.46634636 -0.02354641]
# E -0.08081240758213529
#
# time: 1.8400000000000012
# iterations: 93
# dist: 1.5354796808454618
#  id:atom1, pos:[1.69323692 2.54371482], vel:[-0.44542572  0.0224901 ]
#  id:atom2, pos:[3.22676308 2.46628518], vel:[ 0.44542572 -0.0224901 ]
# E -0.08083514872565109
#
# time: 1.8600000000000012
# iterations: 94
# dist: 1.5529151568765729
#  id:atom1, pos:[1.68453027 2.54415443], vel:[-0.425896    0.02150402]
#  id:atom2, pos:[3.23546973 2.46584557], vel:[ 0.425896   -0.02150402]
# E -0.08085420221934772
#
# time: 1.8800000000000012
# iterations: 95
# dist: 1.5695947637961984
#  id:atom1, pos:[1.67620108 2.54457498], vel:[-0.40761284  0.02058088]
#  id:atom2, pos:[3.24379892 2.46542502], vel:[ 0.40761284 -0.02058088]
# E -0.08087020522933333
#
# time: 1.9000000000000012
# iterations: 96
# dist: 1.585565723645727
#  id:atom1, pos:[1.66822576 2.54497767], vel:[-0.39044945  0.01971428]
#  id:atom2, pos:[3.25177424 2.46502233], vel:[ 0.39044945 -0.01971428]
# E -0.08088368888648981
#
# time: 1.9200000000000013
# iterations: 97
# dist: 1.600870510251446
#  id:atom1, pos:[1.6605831  2.54536355], vel:[-0.37429445  0.01889859]
#  id:atom2, pos:[3.2594169  2.46463645], vel:[ 0.37429445 -0.01889859]
# E -0.08089509074471554
#
# time: 1.9400000000000013
# iterations: 98
# dist: 1.6155474235875917
#  id:atom1, pos:[1.65325398 2.54573361], vel:[-0.35904984  0.01812887]
#  id:atom2, pos:[3.26674602 2.46426639], vel:[ 0.35904984 -0.01812887]
# E -0.08090476913570294
#
# time: 1.9600000000000013
# iterations: 99
# dist: 1.629631088239278
#  id:atom1, pos:[1.64622111 2.54608871], vel:[-0.34462926  0.01740076]
#  id:atom2, pos:[3.27377889 2.46391129], vel:[ 0.34462926 -0.01740076]
# E -0.08091301681678396
#
# time: 1.9800000000000013
# iterations: 100
# dist: 1.643152885213288
#  id:atom1, pos:[1.63946881 2.54642964], vel:[-0.33095637  0.0167104 ]
#  id:atom2, pos:[3.28053119 2.46357036], vel:[ 0.33095637 -0.0167104 ]
# E -0.08092007293966959
#
# time: 2.0000000000000013
# iterations: 101
# dist: 1.6561413259052946
#  id:atom1, pos:[1.63298285 2.54675712], vel:[-0.31796359  0.01605438]
#  id:atom2, pos:[3.28701715 2.46324288], vel:[ 0.31796359 -0.01605438]
# E -0.08092613312299367
#
# time: 2.0200000000000014
# iterations: 102
# dist: 1.6686223762108867
#  id:atom1, pos:[1.62675026 2.54707182], vel:[-0.30559087  0.01542966]
#  id:atom2, pos:[3.29324974 2.46292818], vel:[ 0.30559087 -0.01542966]
# E -0.08093135773797266
#
# time: 2.0400000000000014
# iterations: 103
# dist: 1.680619737824556
#  id:atom1, pos:[1.62075922 2.54737431], vel:[-0.29378471  0.01483356]
#  id:atom2, pos:[3.29924078 2.46262569], vel:[ 0.29378471 -0.01483356]
# E -0.08093587863667144
#
# time: 2.0600000000000014
# iterations: 104
# dist: 1.6921550928369413
#  id:atom1, pos:[1.61499888 2.54766516], vel:[-0.28249737  0.01426364]
#  id:atom2, pos:[3.30500112 2.46233484], vel:[ 0.28249737 -0.01426364]
# E -0.08093980457683377
#
# time: 2.0800000000000014
# iterations: 105
# dist: 1.7032483168777546
#  id:atom1, pos:[1.60945932 2.54794486], vel:[-0.27168606  0.01371777]
#  id:atom2, pos:[3.31054068 2.46205514], vel:[ 0.27168606 -0.01371777]
# E -0.08094322558046596
#
# time: 2.1000000000000014
# iterations: 106
# dist: 1.7139176652840142
#  id:atom1, pos:[1.60413143 2.54821387], vel:[-0.26131236  0.01319399]
#  id:atom2, pos:[3.31586857 2.46178613], vel:[ 0.26131236 -0.01319399]
# E -0.08094621643164789
#
# time: 2.1200000000000014
# iterations: 107
# dist: 1.724179936105114
#  id:atom1, pos:[1.59900683 2.54847262], vel:[-0.25134167  0.01269055]
#  id:atom2, pos:[3.32099317 2.46152738], vel:[ 0.25134167 -0.01269055]
# E -0.0809488394846567
#
# time: 2.1400000000000015
# iterations: 108
# dist: 1.7340506131827966
#  id:atom1, pos:[1.59407777 2.54872149], vel:[-0.24174275  0.01220589]
#  id:atom2, pos:[3.32592223 2.46127851], vel:[ 0.24174275 -0.01220589]
# E -0.08095114692164405
#
# time: 2.1600000000000015
# iterations: 109
# dist: 1.7435439920560463
#  id:atom1, pos:[1.58933712 2.54896085], vel:[-0.23248731  0.01173857]
#  id:atom2, pos:[3.33066288 2.46103915], vel:[ 0.23248731 -0.01173857]
# E -0.08095318257169168
#
# time: 2.1800000000000015
# iterations: 110
# dist: 1.7526732910276592
#  id:atom1, pos:[1.58477827 2.54919103], vel:[-0.22354969  0.0112873 ]
#  id:atom2, pos:[3.33522173 2.46080897], vel:[ 0.22354969 -0.0112873 ]
# E -0.08095498338034468
#
# time: 2.2000000000000015
# iterations: 111
# dist: 1.76145074938034
#  id:atom1, pos:[1.58039513 2.54941234], vel:[-0.21490653  0.0108509 ]
#  id:atom2, pos:[3.33960487 2.46058766], vel:[ 0.21490653 -0.0108509 ]
# E -0.08095658060032049
#
# time: 2.2200000000000015
# iterations: 112
# dist: 1.7698877144359788
#  id:atom1, pos:[1.57618201 2.54962507], vel:[-0.20653652  0.01042829]
#  id:atom2, pos:[3.34381799 2.46037493], vel:[ 0.20653652 -0.01042829]
# E -0.08095800075937623
#
# time: 2.2400000000000015
# iterations: 113
# dist: 1.777994718903773
#  id:atom1, pos:[1.57213367 2.54982948], vel:[-0.19842018  0.01001848]
#  id:atom2, pos:[3.34786633 2.46017052], vel:[ 0.19842018 -0.01001848]
# E -0.08095926644965648
#
# time: 2.2600000000000016
# iterations: 114
# dist: 1.7857815497537044
#  id:atom1, pos:[1.56824521 2.55002581], vel:[-0.19053966  0.00962058]
#  id:atom2, pos:[3.35175479 2.45997419], vel:[ 0.19053966 -0.00962058]
# E -0.08096039697363275
#
# time: 2.2800000000000016
# iterations: 115
# dist: 1.7932573096752797
#  id:atom1, pos:[1.56451208 2.5502143 ], vel:[-0.18287856  0.00923377]
#  id:atom2, pos:[3.35548792 2.4597857 ], vel:[ 0.18287856 -0.00923377]
# E -0.08096140887450004
#
# time: 2.3000000000000016
# iterations: 116
# dist: 1.800430472032141
#  id:atom1, pos:[1.56093006 2.55039516], vel:[-0.17542179  0.00885726]
#  id:atom2, pos:[3.35906994 2.45960484], vel:[ 0.17542179 -0.00885726]
# E -0.08096231637318403
#
# time: 2.3200000000000016
# iterations: 117
# dist: 1.8073089300966447
#  id:atom1, pos:[1.55749521 2.55056859], vel:[-0.16815541  0.00849038]
#  id:atom2, pos:[3.36250479 2.45943141], vel:[ 0.16815541 -0.00849038]
# E -0.08096313172962272
#
# time: 2.3400000000000016
# iterations: 118
# dist: 1.813900041241175
#  id:atom1, pos:[1.55420385 2.55073477], vel:[-0.16106653  0.00813245]
#  id:atom2, pos:[3.36579615 2.45926523], vel:[ 0.16106653 -0.00813245]
# E -0.08096386554243906
#
# time: 2.3600000000000017
# iterations: 119
# dist: 1.8202106666716231
#  id:atom1, pos:[1.55105255 2.55089389], vel:[-0.15414322  0.00778288]
#  id:atom2, pos:[3.36894745 2.45910611], vel:[ 0.15414322 -0.00778288]
# E -0.08096452699832536
#
# time: 2.3800000000000017
# iterations: 120
# dist: 1.8262472072106313
#  id:atom1, pos:[1.54803812 2.55104609], vel:[-0.14737438  0.00744112]
#  id:atom2, pos:[3.37196188 2.45895391], vel:[ 0.14737438 -0.00744112]
# E -0.08096512408024095
#
# time: 2.4000000000000017
# iterations: 121
# dist: 1.8320156355716717
#  id:atom1, pos:[1.54515757 2.55119153], vel:[-0.14074968  0.00710663]
#  id:atom2, pos:[3.37484243 2.45880847], vel:[ 0.14074968 -0.00710663]
# E -0.08096566374176638
#
# time: 2.4200000000000017
# iterations: 122
# dist: 1.8375215255080568
#  id:atom1, pos:[1.54240813 2.55133036], vel:[-0.1342595   0.00677893]
#  id:atom2, pos:[3.37759187 2.45866964], vel:[ 0.1342595  -0.00677893]
# E -0.08096615205355727
#
# time: 2.4400000000000017
# iterations: 123
# dist: 1.8427700781720557
#  id:atom1, pos:[1.53978719 2.55146269], vel:[-0.12789483  0.00645757]
#  id:atom2, pos:[3.38021281 2.45853731], vel:[ 0.12789483 -0.00645757]
# E -0.08096659432672038
#
# time: 2.4600000000000017
# iterations: 124
# dist: 1.8477661459771748
#  id:atom1, pos:[1.53729234 2.55158866], vel:[-0.12164724  0.00614212]
#  id:atom2, pos:[3.38270766 2.45841134], vel:[ 0.12164724 -0.00614212]
# E -0.08096699521704329
#
# time: 2.4800000000000018
# iterations: 125
# dist: 1.8525142542203368
#  id:atom1, pos:[1.5349213  2.55170837], vel:[-0.11550879  0.00583218]
#  id:atom2, pos:[3.3850787  2.45829163], vel:[ 0.11550879 -0.00583218]
# E -0.0809673588132844
#
# time: 2.5000000000000018
# iterations: 126
# dist: 1.8570186206892472
#  id:atom1, pos:[1.53267199 2.55182195], vel:[-0.10947204  0.00552738]
#  id:atom2, pos:[3.38732801 2.45817805], vel:[ 0.10947204 -0.00552738]
# E -0.08096768871215523
#
# time: 2.520000000000002
# iterations: 127
# dist: 1.861283173452989
#  id:atom1, pos:[1.53054242 2.55192947], vel:[-0.10352995  0.00522736]
#  id:atom2, pos:[3.38945758 2.45807053], vel:[ 0.10352995 -0.00522736]
# E -0.08096798808215491
#
# time: 2.540000000000002
# iterations: 128
# dist: 1.8653115670101785
#  id:atom1, pos:[1.52853079 2.55203104], vel:[-0.09767587  0.00493178]
#  id:atom2, pos:[3.39146921 2.45796896], vel:[ 0.09767587 -0.00493178]
# E -0.08096825971803985
#
# time: 2.560000000000002
# iterations: 129
# dist: 1.86910719694836
#  id:atom1, pos:[1.52663539 2.55212674], vel:[-0.0919035   0.00464032]
#  id:atom2, pos:[3.39336461 2.45787326], vel:[ 0.0919035  -0.00464032]
# E -0.08096850608739932
#
# time: 2.580000000000002
# iterations: 130
# dist: 1.8726732132502526
#  id:atom1, pos:[1.52485465 2.55221665], vel:[-0.08620688  0.00435269]
#  id:atom2, pos:[3.39514535 2.45778335], vel:[ 0.08620688 -0.00435269]
# E -0.08096872937055948
#
# time: 2.600000000000002
# iterations: 131
# dist: 1.8760125323666448
#  id:atom1, pos:[1.52318711 2.55230085], vel:[-0.08058029  0.0040686 ]
#  id:atom2, pos:[3.39681289 2.45769915], vel:[ 0.08058029 -0.0040686 ]
# E -0.08096893149482814
#
# time: 2.620000000000002
# iterations: 132
# dist: 1.879127848161807
#  id:atom1, pos:[1.52163144 2.5523794 ], vel:[-0.0750183   0.00378777]
#  id:atom2, pos:[3.39836856 2.4576206 ], vel:[ 0.0750183  -0.00378777]
# E -0.08096911416392542
#
# time: 2.640000000000002
# iterations: 133
# dist: 1.8820216418250468
#  id:atom1, pos:[1.52018638 2.55245236], vel:[-0.06951573  0.00350994]
#  id:atom2, pos:[3.39981362 2.45754764], vel:[ 0.06951573 -0.00350994]
# E -0.08096927888330556
#
# time: 2.660000000000002
# iterations: 134
# dist: 1.88469619083117
#  id:atom1, pos:[1.51885081 2.55251979], vel:[-0.06406758  0.00323485]
#  id:atom2, pos:[3.40114919 2.45748021], vel:[ 0.06406758 -0.00323485]
# E -0.08096942698195889
#
# time: 2.680000000000002
# iterations: 135
# dist: 1.887153577022999
#  id:atom1, pos:[1.51762368 2.55258175], vel:[-0.05866905  0.00296227]
#  id:atom2, pos:[3.40237632 2.45741825], vel:[ 0.05866905 -0.00296227]
# E -0.08096955963118853
#
# time: 2.700000000000002
# iterations: 136
# dist: 1.8893956938805307
#  id:atom1, pos:[1.51650405 2.55263828], vel:[-0.05331553  0.00269197]
#  id:atom2, pos:[3.40349595 2.45736172], vel:[ 0.05331553 -0.00269197]
# E -0.08096967786077497
#
# time: 2.720000000000002
# iterations: 137
# dist: 1.8914242530336538
#  id:atom1, pos:[1.51549106 2.55268943], vel:[-0.04800255  0.00242371]
#  id:atom2, pos:[3.40450894 2.45731057], vel:[ 0.04800255 -0.00242371]
# E -0.08096978257287703
#
# time: 2.740000000000002
# iterations: 138
# dist: 1.8932407900684682
#  id:atom1, pos:[1.51458394 2.55273523], vel:[-0.04272578  0.00215728]
#  id:atom2, pos:[3.40541606 2.45726477], vel:[ 0.04272578 -0.00215728]
# E -0.08096987455396089
#
# time: 2.760000000000002
# iterations: 139
# dist: 1.8948466696710575
#  id:atom1, pos:[1.51378203 2.55277572], vel:[-0.037481    0.00189246]
#  id:atom2, pos:[3.40621797 2.45722428], vel:[ 0.037481   -0.00189246]
# E -0.08096995448500138
#
# time: 2.780000000000002
# iterations: 140
# dist: 1.8962430901469287
#  id:atom1, pos:[1.5130847  2.55281093], vel:[-0.03226412  0.00162906]
#  id:atom2, pos:[3.4069153  2.45718907], vel:[ 0.03226412 -0.00162906]
# E -0.08097002295016122
#
# time: 2.800000000000002
# iterations: 141
# dist: 1.8974310873492162
#  id:atom1, pos:[1.51249146 2.55284089], vel:[-0.02707111  0.00136685]
#  id:atom2, pos:[3.40750854 2.45715911], vel:[ 0.02707111 -0.00136685]
# E -0.08097008044411845
#
# time: 2.820000000000002
# iterations: 142
# dist: 1.8984115380440414
#  id:atom1, pos:[1.51200186 2.55286561], vel:[-0.02189805  0.00110566]
#  id:atom2, pos:[3.40799814 2.45713439], vel:[ 0.02189805 -0.00110566]
# E -0.08097012737818324
#
# time: 2.840000000000002
# iterations: 143
# dist: 1.8991851627370597
#  id:atom1, pos:[1.51161554 2.55288511], vel:[-0.01674105  0.00084528]
#  id:atom2, pos:[3.40838446 2.45711489], vel:[ 0.01674105 -0.00084528]
# E -0.0809701640853221
#
# time: 2.860000000000002
# iterations: 144
# dist: 1.899752527981187
#  id:atom1, pos:[1.51133222 2.55289942], vel:[-0.0115963   0.00058551]
#  id:atom2, pos:[3.40866778 2.45710058], vel:[ 0.0115963  -0.00058551]
# E -0.08097019082418198
#
# time: 2.880000000000002
# iterations: 145
# dist: 1.9001140481816852
#  id:atom1, pos:[1.51115169 2.55290853], vel:[-0.00646001  0.00032617]
#  id:atom2, pos:[3.40884831 2.45709147], vel:[ 0.00646001 -0.00032617]
# E -0.0809702077821891
#
# time: 2.900000000000002
# iterations: 146
# dist: 1.9002699869111725
#  id:atom1, pos:[1.51107382 2.55291246], vel:[-1.32842728e-03  6.70739462e-05]
#  id:atom2, pos:[3.40892618 2.45708754], vel:[ 1.32842728e-03 -6.70739462e-05]
# E -0.08097021507778004
#
# time: 2.920000000000002
# iterations: 147
# dist: 1.9002204577436672
#  id:atom1, pos:[1.51109855 2.55291121], vel:[ 0.00380219 -0.00019198]
#  id:atom2, pos:[3.40890145 2.45708879], vel:[-0.00380219  0.00019198]
# E -0.08097021276180474
#
# time: 2.940000000000002
# iterations: 148
# dist: 1.8999654246134166
#  id:atom1, pos:[1.5112259  2.55290478], vel:[ 0.00893557 -0.00045117]
#  id:atom2, pos:[3.4087741  2.45709522], vel:[-0.00893557  0.00045117]
# E -0.0809702008181279
#
# time: 2.960000000000002
# iterations: 149
# dist: 1.899504701700989
#  id:atom1, pos:[1.51145597 2.55289317], vel:[ 0.01407547 -0.00071069]
#  id:atom2, pos:[3.40854403 2.45710683], vel:[-0.01407547  0.00071069]
# E -0.08097017916343753
#
# time: 2.980000000000002
# iterations: 150
# dist: 1.898837952845833
#  id:atom1, pos:[1.51178892 2.55287636], vel:[ 0.01922565 -0.00097073]
#  id:atom2, pos:[3.40821108 2.45712364], vel:[-0.01922565  0.00097073]
# E -0.08097014764626041
#
# time: 3.000000000000002
# iterations: 151
# dist: 1.8979646904812701
#  id:atom1, pos:[1.512225   2.55285434], vel:[ 0.02438991 -0.00123148]
#  id:atom2, pos:[3.407775   2.45714566], vel:[-0.02438991  0.00123148]
# E -0.08097010604516326
#
# time: 3.0200000000000022
# iterations: 152
# dist: 1.896884274084548
#  id:atom1, pos:[1.51276452 2.5528271 ], vel:[ 0.02957211 -0.00149313]
#  id:atom2, pos:[3.40723548 2.4571729 ], vel:[-0.02957211  0.00149313]
# E -0.0809700540661097
#
# time: 3.0400000000000023
# iterations: 153
# dist: 1.8955959081312028
#  id:atom1, pos:[1.51340788 2.55279461], vel:[ 0.03477613 -0.00175589]
#  id:atom2, pos:[3.40659212 2.45720539], vel:[-0.03477613  0.00175589]
# E -0.08096999133892288
#
# time: 3.0600000000000023
# iterations: 154
# dist: 1.8940986395394412
#  id:atom1, pos:[1.51415556 2.55275686], vel:[ 0.04000596 -0.00201995]
#  id:atom2, pos:[3.40584444 2.45724314], vel:[-0.04000596  0.00201995]
# E -0.08096991741279036
#
# time: 3.0800000000000023
# iterations: 155
# dist: 1.8923913545865516
#  id:atom1, pos:[1.51500812 2.55271382], vel:[ 0.04526564 -0.00228552]
#  id:atom2, pos:[3.40499188 2.45728618], vel:[-0.04526564  0.00228552]
# E -0.08096983175072595
#
# time: 3.1000000000000023
# iterations: 156
# dist: 1.8904727752754413
#  id:atom1, pos:[1.51596619 2.55266544], vel:[ 0.05055934 -0.0025528 ]
#  id:atom2, pos:[3.40403381 2.45733456], vel:[-0.05055934  0.0025528 ]
# E -0.080969733722885
#
# time: 3.1200000000000023
# iterations: 157
# dist: 1.8883414551252022
#  id:atom1, pos:[1.51703049 2.5526117 ], vel:[ 0.05589131 -0.00282202]
#  id:atom2, pos:[3.40296951 2.4573883 ], vel:[-0.05589131  0.00282202]
# E -0.08096962259860467
#
# time: 3.1400000000000023
# iterations: 158
# dist: 1.8859957743550946
#  id:atom1, pos:[1.51820184 2.55255256], vel:[ 0.06126596 -0.00309339]
#  id:atom2, pos:[3.40179816 2.45744744], vel:[-0.06126596  0.00309339]
# E -0.08096949753701438
#
# time: 3.1600000000000024
# iterations: 159
# dist: 1.8834339344264472
#  id:atom1, pos:[1.51948113 2.55248797], vel:[ 0.06668783 -0.00336715]
#  id:atom2, pos:[3.40051887 2.45751203], vel:[-0.06668783  0.00336715]
# E -0.08096935757602901
#
# time: 3.1800000000000024
# iterations: 160
# dist: 1.8806539519015975
#  id:atom1, pos:[1.52086936 2.55241787], vel:[ 0.07216161 -0.00364353]
#  id:atom2, pos:[3.39913064 2.45758213], vel:[-0.07216161  0.00364353]
# E -0.08096920161950302
#
# time: 3.2000000000000024
# iterations: 161
# dist: 1.877653651573125
#  id:atom1, pos:[1.5223676  2.55234223], vel:[ 0.07769219 -0.00392278]
#  id:atom2, pos:[3.3976324  2.45765777], vel:[-0.07769219  0.00392278]
# E -0.08096902842227705
#
# time: 3.2200000000000024
# iterations: 162
# dist: 1.8744306588101047
#  id:atom1, pos:[1.52397704 2.55226096], vel:[ 0.08328466 -0.00420515]
#  id:atom2, pos:[3.39602296 2.45773904], vel:[-0.08328466  0.00420515]
# E -0.0809688365728015
#
# time: 3.2400000000000024
# iterations: 163
# dist: 1.870982391060867
#  id:atom1, pos:[1.52569898 2.55217402], vel:[ 0.08894433 -0.00449091]
#  id:atom2, pos:[3.39430102 2.45782598], vel:[-0.08894433  0.00449091]
# E -0.08096862447295787
#
# time: 3.2600000000000025
# iterations: 164
# dist: 1.8673060484436848
#  id:atom1, pos:[1.52753482 2.55208133], vel:[ 0.09467674 -0.00478035]
#  id:atom2, pos:[3.39246518 2.45791867], vel:[-0.09467674  0.00478035]
# E -0.08096839031462634
#
# time: 3.2800000000000025
# iterations: 165
# dist: 1.8633986033477283
#  id:atom1, pos:[1.52948605 2.55198281], vel:[ 0.10048774 -0.00507375]
#  id:atom2, pos:[3.39051395 2.45801719], vel:[-0.10048774  0.00507375]
# E -0.0809681320524635
#
# time: 3.3000000000000025
# iterations: 166
# dist: 1.8592567889564655
#  id:atom1, pos:[1.53155433 2.55187838], vel:[ 0.10638344 -0.00537143]
#  id:atom2, pos:[3.38844567 2.45812162], vel:[-0.10638344  0.00537143]
# E -0.08096784737224622
#
# time: 3.3200000000000025
# iterations: 167
# dist: 1.8548770865941582
#  id:atom1, pos:[1.53374139 2.55176795], vel:[ 0.11237032 -0.00567372]
#  id:atom2, pos:[3.38625861 2.45823205], vel:[-0.11237032  0.00567372]
# E -0.08096753365401428
#
# time: 3.3400000000000025
# iterations: 168
# dist: 1.8502557117831013
#  id:atom1, pos:[1.53604914 2.55165143], vel:[ 0.1184552  -0.00598095]
#  id:atom2, pos:[3.38395086 2.45834857], vel:[-0.1184552   0.00598095]
# E -0.08096718792908718
#
# time: 3.3600000000000025
# iterations: 169
# dist: 1.8453885988844334
#  id:atom1, pos:[1.5384796  2.55152871], vel:[ 0.12464531 -0.0062935 ]
#  id:atom2, pos:[3.3815204  2.45847129], vel:[-0.12464531  0.0062935 ]
# E -0.08096680682985004
#
# time: 3.3800000000000026
# iterations: 170
# dist: 1.840271384178498
#  id:atom1, pos:[1.54103495 2.55139969], vel:[ 0.13094833 -0.00661174]
#  id:atom2, pos:[3.37896505 2.45860031], vel:[-0.13094833  0.00661174]
# E -0.08096638653096967
#
# time: 3.4000000000000026
# iterations: 171
# dist: 1.8348993872214712
#  id:atom1, pos:[1.54371753 2.55126424], vel:[ 0.13737243 -0.0069361 ]
#  id:atom2, pos:[3.37628247 2.45873576], vel:[-0.13737243  0.0069361 ]
# E -0.08096592268042975
#
# time: 3.4200000000000026
# iterations: 172
# dist: 1.8292675902928999
#  id:atom1, pos:[1.54652985 2.55112224], vel:[ 0.1439263  -0.00726702]
#  id:atom2, pos:[3.37347015 2.45887776], vel:[-0.1439263   0.00726702]
# E -0.08096541031842841
#
# time: 3.4400000000000026
# iterations: 173
# dist: 1.823370615723452
#  id:atom1, pos:[1.54947458 2.55097356], vel:[ 0.15061925 -0.00760495]
#  id:atom2, pos:[3.37052542 2.45902644], vel:[-0.15061925  0.00760495]
# E -0.0809648437817651
#
# time: 3.4600000000000026
# iterations: 174
# dist: 1.8172027008629938
#  id:atom1, pos:[1.55255462 2.55081805], vel:[ 0.15746123 -0.00795041]
#  id:atom2, pos:[3.36744538 2.45918195], vel:[-0.15746123  0.00795041]
# E -0.08096421659082008
#
# time: 3.4800000000000026
# iterations: 175
# dist: 1.8107576704154078
#  id:atom1, pos:[1.55577303 2.55065554], vel:[ 0.16446293 -0.00830394]
#  id:atom2, pos:[3.36422697 2.45934446], vel:[-0.16446293  0.00830394]
# E -0.08096352131559406
#
# time: 3.5000000000000027
# iterations: 176
# dist: 1.804028905827569
#  id:atom1, pos:[1.55913314 2.55048589], vel:[ 0.17163585 -0.00866611]
#  id:atom2, pos:[3.36086686 2.45951411], vel:[-0.17163585  0.00866611]
# E -0.08096274941646697
#
# time: 3.5200000000000027
# iterations: 177
# dist: 1.797009311374637
#  id:atom1, pos:[1.56263847 2.5503089 ], vel:[ 0.17899235 -0.00903755]
#  id:atom2, pos:[3.35736153 2.4596911 ], vel:[-0.17899235  0.00903755]
# E -0.080961891054348
#
# time: 3.5400000000000027
# iterations: 178
# dist: 1.7896912765311943
#  id:atom1, pos:[1.56629283 2.55012439], vel:[ 0.18654583 -0.00941893]
#  id:atom2, pos:[3.35370717 2.45987561], vel:[-0.18654583  0.00941893]
# E -0.08096093486363648
#
# time: 3.5600000000000027
# iterations: 179
# dist: 1.782066634156375
#  id:atom1, pos:[1.5701003  2.54993214], vel:[ 0.19431076 -0.00981099]
#  id:atom2, pos:[3.3498997  2.46006786], vel:[-0.19431076  0.00981099]
# E -0.08095986767985242
#
# time: 3.5800000000000027
# iterations: 180
# dist: 1.774126613949397
#  id:atom1, pos:[1.57406526 2.54973195], vel:[ 0.20230284 -0.01021452]
#  id:atom2, pos:[3.34593474 2.46026805], vel:[-0.20230284  0.01021452]
# E -0.08095867421183064
#
# time: 3.6000000000000028
# iterations: 181
# dist: 1.7658617905478602
#  id:atom1, pos:[1.57819241 2.54952356], vel:[ 0.21053916 -0.01063038]
#  id:atom2, pos:[3.34180759 2.46047644], vel:[-0.21053916  0.01063038]
# E -0.08095733664589085
#
# time: 3.6200000000000028
# iterations: 182
# dist: 1.757262025542478
#  id:atom1, pos:[1.58248683 2.54930673], vel:[ 0.21903832 -0.01105952]
#  id:atom2, pos:[3.33751317 2.46069327], vel:[-0.21903832  0.01105952]
# E -0.08095583416626137
#
# time: 3.640000000000003
# iterations: 183
# dist: 1.7483164025657445
#  id:atom1, pos:[1.58695395 2.54908118], vel:[ 0.22782067 -0.01150295]
#  id:atom2, pos:[3.33304605 2.46091882], vel:[-0.22782067  0.01150295]
# E -0.08095414237206142
#
# time: 3.660000000000003
# iterations: 184
# dist: 1.7390131544750604
#  id:atom1, pos:[1.59159965 2.54884661], vel:[ 0.23690847 -0.0119618 ]
#  id:atom2, pos:[3.32840035 2.46115339], vel:[-0.23690847  0.0119618 ]
# E -0.08095223256610456
#
# time: 3.680000000000003
# iterations: 185
# dist: 1.7293395814889707
#  id:atom1, pos:[1.59643029 2.54860271], vel:[ 0.24632616 -0.01243731]
#  id:atom2, pos:[3.32356971 2.46139729], vel:[-0.24632616  0.01243731]
# E -0.08095007088438125
#
# time: 3.700000000000003
# iterations: 186
# dist: 1.7192819589435862
#  id:atom1, pos:[1.6014527  2.54834912], vel:[ 0.25610062 -0.01293084]
#  id:atom2, pos:[3.3185473  2.46165088], vel:[-0.25610062  0.01293084]
# E -0.08094761722694015
#
# time: 3.720000000000003
# iterations: 187
# dist: 1.7088254331092472
#  id:atom1, pos:[1.60667431 2.54808548], vel:[ 0.26626151 -0.01344388]
#  id:atom2, pos:[3.31332569 2.46191452], vel:[-0.26626151  0.01344388]
# E -0.08094482394056612
#
# time: 3.740000000000003
# iterations: 188
# dist: 1.697953903238187
#  id:atom1, pos:[1.61210316 2.54781137], vel:[ 0.27684166 -0.01397808]
#  id:atom2, pos:[3.30789684 2.46218863], vel:[-0.27684166  0.01397808]
# E -0.08094163419059743
#
# time: 3.760000000000003
# iterations: 189
# dist: 1.6866498876945342
#  id:atom1, pos:[1.61774798 2.54752635], vel:[ 0.28787743 -0.01453529]
#  id:atom2, pos:[3.30225202 2.46247365], vel:[-0.28787743  0.01453529]
# E -0.08093797994281346
#
# time: 3.780000000000003
# iterations: 190
# dist: 1.674894371639315
#  id:atom1, pos:[1.62361826 2.54722995], vel:[ 0.29940927 -0.01511755]
#  id:atom2, pos:[3.29638174 2.46277005], vel:[-0.29940927  0.01511755]
# E -0.080933779455907
#
# time: 3.800000000000003
# iterations: 191
# dist: 1.662666633295125
#  id:atom1, pos:[1.62972435 2.54692165], vel:[ 0.31148229 -0.01572713]
#  id:atom2, pos:[3.29027565 2.46307835], vel:[-0.31148229  0.01572713]
# E -0.08092893416009443
#
# time: 3.820000000000003
# iterations: 192
# dist: 1.6499440452872165
#  id:atom1, pos:[1.63607755 2.54660087], vel:[ 0.32414691 -0.01636658]
#  id:atom2, pos:[3.28392245 2.46339913], vel:[-0.32414691  0.01636658]
# E -0.08092332476775442
#
# time: 3.840000000000003
# iterations: 193
# dist: 1.6367018469396242
#  id:atom1, pos:[1.64269022 2.54626699], vel:[ 0.33745965 -0.01703876]
#  id:atom2, pos:[3.27730978 2.46373301], vel:[-0.33745965  0.01703876]
# E -0.08091680642853682
#
# time: 3.860000000000003
# iterations: 194
# dist: 1.6229128826889996
#  id:atom1, pos:[1.64957593 2.54591932], vel:[ 0.35148408 -0.01774687]
#  id:atom2, pos:[3.27042407 2.46408068], vel:[-0.35148408  0.01774687]
# E -0.08090920270730916
#
# time: 3.880000000000003
# iterations: 195
# dist: 1.6085473009637088
#  id:atom1, pos:[1.65674959 2.54555711], vel:[ 0.36629184 -0.01849453]
#  id:atom2, pos:[3.26325041 2.46444289], vel:[-0.36629184  0.01849453]
# E -0.0809002981366258
#
# time: 3.900000000000003
# iterations: 196
# dist: 1.5935722069738683
#  id:atom1, pos:[1.66422761 2.54517954], vel:[ 0.38196392 -0.01928583]
#  id:atom2, pos:[3.25577239 2.46482046], vel:[-0.38196392  0.01928583]
# E -0.08088982909394521
#
# time: 3.920000000000003
# iterations: 197
# dist: 1.577951261908628
#  id:atom1, pos:[1.67202814 2.54478568], vel:[ 0.39859208 -0.02012541]
#  id:atom2, pos:[3.24797186 2.46521432], vel:[-0.39859208  0.02012541]
# E -0.08087747281505273
#
# time: 3.940000000000003
# iterations: 198
# dist: 1.5616442201300686
#  id:atom1, pos:[1.68017129 2.54437452], vel:[ 0.41628055 -0.02101852]
#  id:atom2, pos:[3.23982871 2.46562548], vel:[-0.41628055  0.02101852]
# E -0.08086283455584242
#
# time: 3.960000000000003
# iterations: 199
# dist: 1.544606395272335
#  id:atom1, pos:[1.68867937 2.54394494], vel:[ 0.43514785 -0.02197116]
#  id:atom2, pos:[3.23132063 2.46605506], vel:[-0.43514785  0.02197116]
# E -0.08084543340964037
#
# time: 3.980000000000003
# iterations: 200
# dist: 1.5267880460553669
#  id:atom1, pos:[1.69757721 2.54349568], vel:[ 0.45532899 -0.02299013]
#  id:atom2, pos:[3.22242279 2.46650432], vel:[-0.45532899  0.02299013]
# E -0.08082468838819387
#
# time: 4.000000000000003
# iterations: 201
# dist: 1.5081336737736832
#  id:atom1, pos:[1.70689253 2.54302533], vel:[ 0.47697763 -0.02408319]
#  id:atom2, pos:[3.21310747 2.46697467], vel:[-0.47697763  0.02408319]
# E -0.08079990870893392
#
# time: 4.020000000000002
# iterations: 202
# dist: 1.4885812270652323
#  id:atom1, pos:[1.71665631 2.54253235], vel:[ 0.50026842 -0.02525917]
#  id:atom2, pos:[3.20334369 2.46746765], vel:[-0.50026842  0.02525917]
# E -0.08077029707135225
#
# time: 4.040000000000002
# iterations: 203
# dist: 1.468061218005543
#  id:atom1, pos:[1.72690326 2.54201497], vel:[ 0.52539891 -0.02652804]
#  id:atom2, pos:[3.19309674 2.46798503], vel:[-0.52539891  0.02652804]
# E -0.08073498465263074
#
# time: 4.060000000000001
# iterations: 204
# dist: 1.4464957710830175
#  id:atom1, pos:[1.73767227 2.54147123], vel:[ 0.55259053 -0.02790098]
#  id:atom2, pos:[3.18232773 2.46852877], vel:[-0.55259053  0.02790098]
# E -0.08069313698251568
#
# time: 4.080000000000001
# iterations: 205
# dist: 1.4237976611856034
#  id:atom1, pos:[1.74900688 2.54089893], vel:[ 0.58208734 -0.02939031]
#  id:atom2, pos:[3.17099312 2.46910107], vel:[-0.58208734  0.02939031]
# E -0.08064421200003191
#
# time: 4.1000000000000005
# iterations: 206
# dist: 1.3998694634708848
#  id:atom1, pos:[1.76095576 2.54029561], vel:[ 0.61415009 -0.0310092 ]
#  id:atom2, pos:[3.15904424 2.46970439], vel:[-0.61415009  0.0310092 ]
# E -0.0805885391395087
#
# time: 4.12
# iterations: 207
# dist: 1.374603065808005
#  id:atom1, pos:[1.77357289 2.53965856], vel:[ 0.649041   -0.03277089]
#  id:atom2, pos:[3.14642711 2.47034144], vel:[-0.649041    0.03277089]
# E -0.08052857148743264
#
# time: 4.14
# iterations: 208
# dist: 1.3478800394941763
#  id:atom1, pos:[1.7869174  2.53898478], vel:[ 0.68699023 -0.03468699]
#  id:atom2, pos:[3.1330826  2.47101522], vel:[-0.68699023  0.03468699]
# E -0.08047154804173334
#
# time: 4.159999999999999
# iterations: 209
# dist: 1.3195738367151395
#  id:atom1, pos:[1.8010525  2.53827108], vel:[ 0.72812665 -0.03676402]
#  id:atom2, pos:[3.1189475  2.47172892], vel:[-0.72812665  0.03676402]
# E -0.08043510855349267
#
# time: 4.179999999999999
# iterations: 210
# dist: 1.2895557042675405
#  id:atom1, pos:[1.81604247 2.53751422], vel:[ 0.77233891 -0.03899635]
#  id:atom2, pos:[3.10395753 2.47248578], vel:[-0.77233891  0.03899635]
# E -0.0804590464703605
#
# time: 4.199999999999998
# iterations: 211
# dist: 1.2577080153071356
#  id:atom1, pos:[1.83194605 2.53671123], vel:[ 0.81899916 -0.04135229]
# ...
#  id:atom2, pos:[3.39019886 2.4580331 ], vel:[-0.10140179  0.0051199 ]
# E -0.08096818332402693
#
# time: 198.6200000000278
# iterations: 9932
# dist: 1.8585889422185855
#  id:atom1, pos:[1.53188782 2.55186154], vel:[ 0.10731129 -0.00541828]
#  id:atom2, pos:[3.38811218 2.45813846], vel:[-0.10731129  0.00541828]
# E -0.08096789429367668
#
# time: 198.6400000000278
# iterations: 9933
# dist: 1.8541717920143719
#  id:atom1, pos:[1.53409359 2.55175017], vel:[ 0.11331301 -0.00572131]
#  id:atom2, pos:[3.38590641 2.45824983], vel:[-0.11331301  0.00572131]
# E -0.08096757578621497
#
# time: 198.66000000002782
# iterations: 9934
# dist: 1.8495123537182088
#  id:atom1, pos:[1.53642034 2.55163269], vel:[ 0.11941383 -0.00602935]
#  id:atom2, pos:[3.38357966 2.45836731], vel:[-0.11941383  0.00602935]
# E -0.0809672247742188
#
# time: 198.68000000002783
# iterations: 9935
# dist: 1.8446065163371503
#  id:atom1, pos:[1.53887014 2.55150899], vel:[ 0.12562105 -0.00634276]
#  id:atom2, pos:[3.38112986 2.45849101], vel:[-0.12562105  0.00634276]
# E -0.08096683782275946
#
# time: 198.70000000002784
# iterations: 9936
# dist: 1.8394498680061233
#  id:atom1, pos:[1.54144519 2.55137898], vel:[ 0.13194241 -0.00666194]
#  id:atom2, pos:[3.37855481 2.45862102], vel:[-0.13194241  0.00666194]
# E -0.08096641102914481
#
# time: 198.72000000002785
# iterations: 9937
# dist: 1.834037677059472
#  id:atom1, pos:[1.54414784 2.55124252], vel:[ 0.13838617 -0.00698729]
#  id:atom2, pos:[3.37585216 2.45875748], vel:[-0.13838617  0.00698729]
# E -0.08096593995219756
#
# time: 198.74000000002786
# iterations: 9938
# dist: 1.828364871162292
#  id:atom1, pos:[1.54698063 2.55109948], vel:[ 0.14496112 -0.00731927]
#  id:atom2, pos:[3.37301937 2.45890052], vel:[-0.14496112  0.00731927]
# E -0.08096541952905831
#
# time: 198.76000000002787
# iterations: 9939
# dist: 1.822426014286574
#  id:atom1, pos:[1.54994628 2.55094974], vel:[ 0.15167666 -0.00765834]
#  id:atom2, pos:[3.37005372 2.45905026], vel:[-0.15167666  0.00765834]
# E -0.08096484397706027
#
# time: 198.78000000002788
# iterations: 9940
# dist: 1.8162152812873273
#  id:atom1, pos:[1.5530477  2.55079315], vel:[ 0.15854284 -0.00800503]
#  id:atom2, pos:[3.3669523  2.45920685], vel:[-0.15854284  0.00800503]
# E -0.08096420667769308
#
# time: 198.8000000000279
# iterations: 9941
# dist: 1.8097264297993807
#  id:atom1, pos:[1.556288   2.55062954], vel:[ 0.16557049 -0.00835986]
#  id:atom2, pos:[3.363712   2.45937046], vel:[-0.16557049  0.00835986]
# E -0.08096350003900543
#
# time: 198.8200000000279
# iterations: 9942
# dist: 1.8029527691356555
#  id:atom1, pos:[1.55967052 2.55045876], vel:[ 0.17277121 -0.00872343]
#  id:atom2, pos:[3.36032948 2.45954124], vel:[-0.17277121  0.00872343]
# E -0.0809627153319678
#
# time: 198.8400000000279
# iterations: 9943
# dist: 1.7958871258213809
#  id:atom1, pos:[1.56319885 2.55028061], vel:[ 0.18015755 -0.00909638]
#  id:atom2, pos:[3.35680115 2.45971939], vel:[-0.18015755  0.00909638]
# E -0.08096184249528735
#
# time: 198.86000000002792
# iterations: 9944
# dist: 1.788521805344802
#  id:atom1, pos:[1.56687682 2.5500949 ], vel:[ 0.18774304 -0.00947938]
#  id:atom2, pos:[3.35312318 2.4599051 ], vel:[-0.18774304  0.00947938]
# E -0.08096086990187655
#
# time: 198.88000000002793
# iterations: 9945
# dist: 1.7808485496420723
#  id:atom1, pos:[1.57070857 2.54990143], vel:[ 0.19554235 -0.00987318]
#  id:atom2, pos:[3.34929143 2.46009857], vel:[-0.19554235  0.00987318]
# E -0.08095978407855503
#
# time: 198.90000000002794
# iterations: 9946
# dist: 1.7728584897604875
#  id:atom1, pos:[1.57469852 2.54969997], vel:[ 0.20357138 -0.01027857]
#  id:atom2, pos:[3.34530148 2.46030003], vel:[-0.20357138  0.01027857]
# E -0.08095856936852938
#
# time: 198.92000000002795
# iterations: 9947
# dist: 1.7645420930580547
#  id:atom1, pos:[1.57885142 2.54949029], vel:[ 0.21184745 -0.01069644]
#  id:atom2, pos:[3.34114858 2.46050971], vel:[-0.21184745  0.01069644]
# E -0.08095720752362032
#
# time: 198.94000000002796
# iterations: 9948
# dist: 1.7558891041961622
#  id:atom1, pos:[1.58317241 2.54927212], vel:[ 0.22038943 -0.01112774]
#  id:atom2, pos:[3.33682759 2.46072788], vel:[-0.22038943  0.01112774]
# E -0.08095567720995628
#
# time: 198.96000000002797
# iterations: 9949
# dist: 1.7468884790629506
#  id:atom1, pos:[1.587667   2.54904518], vel:[ 0.22921793 -0.0115735 ]
#  id:atom2, pos:[3.332333   2.46095482], vel:[-0.22921793  0.0115735 ]
# E -0.08095395340672837
#
# time: 198.98000000002799
# iterations: 9950
# dist: 1.7375283106243946
#  id:atom1, pos:[1.59234113 2.54880918], vel:[ 0.23835553 -0.01203487]
#  id:atom2, pos:[3.32765887 2.46119082], vel:[-0.23835553  0.01203487]
# E -0.08095200667236783
#
# time: 199.000000000028
# iterations: 9951
# dist: 1.7277957455339448
#  id:atom1, pos:[1.59720122 2.54856378], vel:[ 0.24782706 -0.0125131 ]
#  id:atom2, pos:[3.32279878 2.46143622], vel:[-0.24782706  0.0125131 ]
# E -0.08094980224585915
#
# time: 199.020000000028
# iterations: 9952
# dist: 1.7176768901348805
#  id:atom1, pos:[1.60225421 2.54830865], vel:[ 0.25765979 -0.01300956]
#  id:atom2, pos:[3.31774579 2.46169135], vel:[-0.25765979  0.01300956]
# E -0.08094729894245359
#
# time: 199.04000000002802
# iterations: 9953
# dist: 1.7071567042563638
#  id:atom1, pos:[1.60750761 2.5480434 ], vel:[ 0.26788387 -0.01352579]
#  id:atom2, pos:[3.31249239 2.4619566 ], vel:[-0.26788387  0.01352579]
# E -0.08094444779234017
#
# time: 199.06000000002803
# iterations: 9954
# dist: 1.6962188809276477
#  id:atom1, pos:[1.61296957 2.54776762], vel:[ 0.27853262 -0.01406346]
#  id:atom2, pos:[3.30703043 2.46223238], vel:[-0.27853262  0.01406346]
# E -0.08094119035729197
#
# time: 199.08000000002804
# iterations: 9955
# dist: 1.6848457098068221
#  id:atom1, pos:[1.61864892 2.54748086], vel:[ 0.28964302 -0.01462444]
#  id:atom2, pos:[3.30135108 2.46251914], vel:[-0.28964302  0.01462444]
# E -0.08093745664331356
#
# time: 199.10000000002805
# iterations: 9956
# dist: 1.673017921731683
#  id:atom1, pos:[1.62455529 2.54718264], vel:[ 0.30125622 -0.0152108 ]
#  id:atom2, pos:[3.29544471 2.46281736], vel:[-0.30125622  0.0152108 ]
# E -0.08093316250621956
# time: 199.12000000002806
# iterations: 9957
# dist: 1.6607145113405644
#  id:atom1, pos:[1.63069917 2.54687243], vel:[ 0.31341809 -0.01582487]
#  id:atom2, pos:[3.28930083 2.46312757], vel:[-0.31341809  0.01582487]
# E -0.08092820642136984
#
# time: 199.14000000002807
# iterations: 9958
# dist: 1.647912534169591
#  id:atom1, pos:[1.63709201 2.54654965], vel:[ 0.32617996 -0.01646923]
#  id:atom2, pos:[3.28290799 2.46345035], vel:[-0.32617996  0.01646923]
# E -0.08092246545843852
#
# time: 199.16000000002808
# iterations: 9959
# dist: 1.6345868739998402
#  id:atom1, pos:[1.64374637 2.54621366], vel:[ 0.33959938 -0.0171468 ]
#  id:atom2, pos:[3.27625363 2.46378634], vel:[-0.33959938  0.0171468 ]
# E -0.08091579026825473
#
# time: 199.1800000000281
# iterations: 9960
# dist: 1.620709975496314
#  id:atom1, pos:[1.65067599 2.54586378], vel:[ 0.3537411  -0.01786083]
#  id:atom2, pos:[3.26932401 2.46413622], vel:[-0.3537411   0.01786083]
# E -0.0809079988551254
#
# time: 199.2000000000281
# iterations: 9961
# dist: 1.606251536350664
#  id:atom1, pos:[1.65789601 2.54549923], vel:[ 0.36867814 -0.01861502]
#  id:atom2, pos:[3.26210399 2.46450077], vel:[-0.36867814  0.01861502]
# E -0.08089886888378903
#
# time: 199.2200000000281
# iterations: 9962
# dist: 1.5911781522268056
#  id:atom1, pos:[1.66542311 2.54511918], vel:[ 0.38449307 -0.01941353]
#  id:atom2, pos:[3.25457689 2.46488082], vel:[-0.38449307  0.01941353]
# E -0.0808881282752946
#
# time: 199.24000000002812
# iterations: 9963
# dist: 1.5754529068581336
#  id:atom1, pos:[1.67327573 2.54472269], vel:[ 0.40127949 -0.0202611 ]
#  id:atom2, pos:[3.24672427 2.46527731], vel:[-0.40127949  0.0202611 ]
# E -0.08087544392265633
#
# time: 199.26000000002813
# iterations: 9964
# dist: 1.5590348987581069
#  id:atom1, pos:[1.68147429 2.54430873], vel:[ 0.41914371 -0.02116309]
#  id:atom2, pos:[3.23852571 2.46569127], vel:[-0.41914371  0.02116309]
# E -0.080860408590777
#
# time: 199.28000000002814
# iterations: 9965
# dist: 1.5418786953866919
#  id:atom1, pos:[1.69004148 2.54387616], vel:[ 0.43820669 -0.0221256 ]
#  id:atom2, pos:[3.22995852 2.46612384], vel:[-0.43820669  0.0221256 ]
# E -0.08084252662860611
#
# time: 199.30000000002815
# iterations: 9966
# dist: 1.5239337056562525
#  id:atom1, pos:[1.69900256 2.54342371], vel:[ 0.4586062 -0.0231556]
#  id:atom2, pos:[3.22099744 2.46657629], vel:[-0.4586062  0.0231556]
# E -0.0808212003622909
#
# time: 199.32000000002816
# iterations: 9967
# dist: 1.5051434630991138
#  id:atom1, pos:[1.70838573 2.54294994], vel:[ 0.48049902 -0.02426099]
#  id:atom2, pos:[3.21161427 2.46705006], vel:[-0.48049902  0.02426099]
# E -0.08079572165660592
#
# time: 199.34000000002817
# iterations: 9968
# dist: 1.4854448162238958
#  id:atom1, pos:[1.71822252 2.54245327], vel:[ 0.50406328 -0.02545078]
#  id:atom2, pos:[3.20177748 2.46754673], vel:[-0.50406328  0.02545078]
# E -0.08076527854975918
#
# time: 199.36000000002818
# iterations: 9969
# dist: 1.464767032093627
#  id:atom1, pos:[1.72854826 2.54193191], vel:[ 0.5295002  -0.02673512]
#  id:atom2, pos:[3.19145174 2.46806809], vel:[-0.5295002   0.02673512]
# E -0.08072899799494232
#
# time: 199.3800000000282
# iterations: 9970
# dist: 1.4430308386762731
#  id:atom1, pos:[1.73940253 2.54138386], vel:[ 0.55703494 -0.02812539]
#  id:atom2, pos:[3.18059747 2.46861614], vel:[-0.55703494  0.02812539]
# E -0.08068606860680477
#
# time: 199.4000000000282
# iterations: 9971
# dist: 1.4201474698687586
#  id:atom1, pos:[1.75082966 2.54080689], vel:[ 0.58691469 -0.02963405]
#  id:atom2, pos:[3.16917034 2.46919311], vel:[-0.58691469  0.02963405]
# E -0.08063603452265211
#
# time: 199.4200000000282
# iterations: 9972
# dist: 1.3960178509776142
#  id:atom1, pos:[1.76287912 2.5401985 ], vel:[ 0.61940179 -0.03127437]
#  id:atom2, pos:[3.15712088 2.4698015 ], vel:[-0.61940179  0.03127437]
# E -0.08057944967983838
#
# time: 199.44000000002822
# iterations: 9973
# dist: 1.3705322038823728
#  id:atom1, pos:[1.77560573 2.53955592], vel:[ 0.65475628 -0.03305946]
#  id:atom2, pos:[3.14439427 2.47044408], vel:[-0.65475628  0.03305946]
# E -0.08051928748400483
#
# time: 199.46000000002823
# iterations: 9974
# dist: 1.3435706224394695
#  id:atom1, pos:[1.78906937 2.53887612], vel:[ 0.69319834 -0.03500045]
#  id:atom2, pos:[3.13093063 2.47112388], vel:[-0.69319834  0.03500045]
# E -0.08046393310747108
#
# time: 199.48000000002824
# iterations: 9975
# dist: 1.3150056929456835
#  id:atom1, pos:[1.80333366 2.5381559 ], vel:[ 0.73483098 -0.03710253]
#  id:atom2, pos:[3.11666634 2.4718441 ], vel:[-0.73483098  0.03710253]
# E -0.0804334880937756
#
# time: 199.50000000002825
# iterations: 9976
# dist: 1.284709257496546
#  id:atom1, pos:[1.81846261 2.53739202], vel:[ 0.77948528 -0.03935718]
#  id:atom2, pos:[3.10153739 2.47260798], vel:[-0.77948528  0.03935718]
# E -0.08047294439081987
#
# time: 199.52000000002826
# iterations: 9977
# dist: 1.2525674336286787
#  id:atom1, pos:[1.83451307 2.53658161], vel:[ 0.82641306 -0.04172662]
#  id:atom2, pos:[3.08548693 2.47341839], vel:[-0.82641306  0.04172662]
# E -0.08067916202640146
#
# time: 199.54000000002827
# iterations: 9978
# dist: 1.2185119935678088
#  id:atom1, pos:[1.85151913 2.53572296], vel:[ 0.87367955 -0.04411317]
#  id:atom2, pos:[3.06848087 2.47427704], vel:[-0.87367955  0.04411317]
# E -0.08125316496451629
#
# time: 199.56000000002828
# iterations: 9979
# dist: 1.1825840330738964
#  id:atom1, pos:[1.86946026 2.53481709], vel:[ 0.91697488 -0.0462992 ]
#  id:atom2, pos:[3.05053974 2.47518291], vel:[-0.91697488  0.0462992 ]
# E -0.08258681945593205
#
# time: 199.5800000000283
# iterations: 9980
# dist: 1.1450605547428951
#  id:atom1, pos:[1.88819812 2.53387099], vel:[ 0.94736166 -0.04783347]
#  id:atom2, pos:[3.03180188 2.47612901], vel:[-0.94736166  0.04783347]
# E -0.08533660955521405
#
# time: 199.6000000000283
# iterations: 9981
# dist: 1.1066985548705288
#  id:atom1, pos:[1.90735472 2.53290375], vel:[ 0.94738962 -0.04783488]
#  id:atom2, pos:[3.01264528 2.47709625], vel:[-0.94738962  0.04783488]
# E -0.09014638160822108
#
# time: 199.6200000000283
# iterations: 9982
# dist: 1.0691728368943305
#  id:atom1, pos:[1.92609371 2.53195759], vel:[ 0.88608988 -0.04473978]
#  id:atom2, pos:[2.99390629 2.47804241], vel:[-0.88608988  0.04473978]
# E -0.09582687925480027
#
# time: 199.64000000002832
# iterations: 9983
# dist: 1.0357210631087397
#  id:atom1, pos:[1.94279832 2.53111416], vel:[ 0.71895111 -0.03630074]
#  id:atom2, pos:[2.97720168 2.47888584], vel:[-0.71895111  0.03630074]
# E -0.09494783702811138
#
# time: 199.66000000002833
# iterations: 9984
# dist: 1.01158348016558
#  id:atom1, pos:[1.95485175 2.53050556], vel:[ 0.41107128 -0.0207555 ]
#  id:atom2, pos:[2.96514825 2.47949444], vel:[-0.41107128  0.0207555 ]
# E -0.07765491600996788
#
# time: 199.68000000002834
# iterations: 9985
# dist: 1.0027934688576812
#  id:atom1, pos:[1.95924117 2.53028394], vel:[-0.00778573  0.00039311]
#  id:atom2, pos:[2.96075883 2.47971606], vel:[ 0.00778573 -0.00039311]
# E -0.06305506640946346
#
# time: 199.70000000002835
# iterations: 9986
# dist: 1.0122071316664418
#  id:atom1, pos:[1.95454032 2.53052129], vel:[-0.42430103  0.02142349]
#  id:atom2, pos:[2.96545968 2.47947871], vel:[ 0.42430103 -0.02142349]
# E -0.0784661534031412
#
# time: 199.72000000002836
# iterations: 9987
# dist: 1.0367807917631968
#  id:atom1, pos:[1.94226913 2.53114088], vel:[-0.72716485  0.03671546]
#  id:atom2, pos:[2.97773087 2.47885912], vel:[ 0.72716485 -0.03671546]
# E -0.09523538798865017
#
# time: 199.74000000002837
# iterations: 9988
# dist: 1.0704544244595153
#  id:atom1, pos:[1.92545373 2.53198991], vel:[-0.88977749  0.04492597]
#  id:atom2, pos:[2.99454627 2.47801009], vel:[ 0.88977749 -0.04492597]
# E -0.09566863897834388
#
# time: 199.76000000002838
# iterations: 9989
# dist: 1.108053667756451
#  id:atom1, pos:[1.90667803 2.53293791], vel:[-0.94820563  0.04787608]
#  id:atom2, pos:[3.01332197 2.47706209], vel:[ 0.94820563 -0.04787608]
# E -0.08994271390938213
#
# time: 199.7800000000284
# iterations: 9990
# dist: 1.1464075064804304
#  id:atom1, pos:[1.88752551 2.53390495], vel:[-0.94666926  0.04779851]
#  id:atom2, pos:[3.03247449 2.47609505], vel:[ 0.94666926 -0.04779851]
# E -0.085206470803606
#
# time: 199.8000000000284
# iterations: 9991
# dist: 1.1838836833212634
#  id:atom1, pos:[1.86881126 2.53484986], vel:[-0.91559321  0.04622944]
#  id:atom2, pos:[3.05118874 2.47515014], vel:[ 0.91559321 -0.04622944]
# E -0.08252011853692665
#
# time: 199.82000000002841
# iterations: 9992
# dist: 1.2197482714783567
#  id:atom1, pos:[1.85090178 2.53575413], vel:[-0.87204145  0.04403046]
#  id:atom2, pos:[3.06909822 2.47424587], vel:[ 0.87204145 -0.04403046]
# E -0.0812229471688738
#
# time: 199.84000000002843
# iterations: 9993
# dist: 1.2537358684739486
#  id:atom1, pos:[1.8339296  2.53661107], vel:[-0.82473233  0.04164176]
#  id:atom2, pos:[3.0860704  2.47338893], vel:[ 0.82473233 -0.04164176]
# E -0.08066720011644413
#
# time: 199.86000000002844
# iterations: 9994
# dist: 1.2858109058295986
#  id:atom1, pos:[1.81791248 2.5374198 ], vel:[-0.77786143  0.03927519]
#  id:atom2, pos:[3.10208752 2.4725802 ], vel:[ 0.77786143 -0.03927519]
# E -0.08046948033551349
#
# time: 199.88000000002845
# iterations: 9995
# dist: 1.3160440542976122
#  id:atom1, pos:[1.80281514 2.53818208], vel:[-0.73330586  0.03702553]
#  id:atom2, pos:[3.11718486 2.47181792], vel:[ 0.73330586 -0.03702553]
# E -0.08043372734664256
#
# time: 199.90000000002846
# iterations: 9996
# dist: 1.3445501058252853
#  id:atom1, pos:[1.78858025 2.53890082], vel:[-0.69178536  0.0349291 ]
#  id:atom2, pos:[3.13141975 2.47109918], vel:[ 0.69178536 -0.0349291 ]
# E -0.08046561709955247
#
# time: 199.92000000002847
# iterations: 9997
# dist: 1.371457382380522
#  id:atom1, pos:[1.77514373 2.53957925], vel:[-0.65345519  0.03299377]
#  id:atom2, pos:[3.14485627 2.47042075], vel:[ 0.65345519 -0.03299377]
# E -0.08052138810186266
#
# time: 199.94000000002848
# iterations: 9998
# dist: 1.3968931145493433
#  id:atom1, pos:[1.76244204 2.54022057], vel:[-0.61820619  0.031214  ]
#  id:atom2, pos:[3.15755796 2.46977943], vel:[ 0.61820619 -0.031214  ]
# E -0.08058152209537578
#
# time: 199.9600000000285
# iterations: 9999
# dist: 1.4209768787090218
#  id:atom1, pos:[1.75041548 2.54082781], vel:[-0.58581577  0.02957857]
#  id:atom2, pos:[3.16958452 2.46917219], vel:[ 0.58581577 -0.02957857]
# E -0.0806379057774243
#
# time: 199.9800000000285
# iterations: 10000
# dist: 1.4438180765045603
#  id:atom1, pos:[1.73900941 2.54140371], vel:[-0.55602331  0.02807431]
#  id:atom2, pos:[3.18099059 2.46859629], vel:[ 0.55602331 -0.02807431]
# E -0.08068768940765675

# %%
# using natural units
plt.plot(e.times[:1000],e.dist[:1000])
plt.xlabel('Simulation Time')
plt.ylabel('Distance Between Atoms')
# Out:
# Text(0, 0.5, 'Distance Between Atoms')
