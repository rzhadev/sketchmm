# %%
import engine
from engine import Engine
from config import Config
import importlib
importlib.reload(engine)
e = Engine()
# Out:
# Loaded configuration from D:\sketchmm\./setup.yaml

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
e.fixed_steps_simulation(1000)
# Out:
# time: 0.00
# iterations: 1
#  id:atom1, pos:[1.511083 2.552912], vel:[ 2.56524830e-04 -1.29522578e-05]
#  id:atom2, pos:[3.408917 2.457088], vel:[-2.56524830e-04  1.29522578e-05]
# E: -0.08097664173987539
# avgT: 0.0
# avgP: 0.0
#
# time: 0.00
# iterations: 2
#  id:atom1, pos:[1.51108403 2.55291195], vel:[ 7.69576357e-04 -3.88568678e-05]
#  id:atom2, pos:[3.40891597 2.45708805], vel:[-7.69576357e-04  3.88568678e-05]
# E: -0.08097664173891458
# avgT: 0.0
# avgP: 0.0
#
# time: 0.00
# iterations: 3
#  id:atom1, pos:[1.51108608 2.55291184], vel:[ 1.28263349e-03 -6.47617607e-05]
#  id:atom2, pos:[3.40891392 2.45708816], vel:[-1.28263349e-03  6.47617607e-05]
# E: -0.08097664173699297
# avgT: 0.0
# avgP: 0.0
#
# time: 0.01
# iterations: 4
#  id:atom1, pos:[1.51108916 2.55291169], vel:[ 1.79569996e-03 -9.06671252e-05]
#  id:atom2, pos:[3.40891084 2.45708831], vel:[-1.79569996e-03  9.06671252e-05]
# E: -0.08097664173411036
# avgT: 0.0
# avgP: 0.0
#
# time: 0.01
# iterations: 5
#  id:atom1, pos:[1.51109326 2.55291148], vel:[ 0.00230878 -0.00011657]
#  id:atom2, pos:[3.40890674 2.45708852], vel:[-0.00230878  0.00011657]
# E: -0.08097664173026659
# avgT: 0.0
# avgP: 0.0
#
# time: 0.01
# iterations: 6
#  id:atom1, pos:[1.51109839 2.55291122], vel:[ 0.00282188 -0.00014248]
#  id:atom2, pos:[3.40890161 2.45708878], vel:[-0.00282188  0.00014248]
# E: -0.0809766417254614
# avgT: 0.0
# avgP: 0.0
#
# time: 0.01
# iterations: 7
#  id:atom1, pos:[1.51110455 2.55291091], vel:[ 0.00333499 -0.00016839]
#  id:atom2, pos:[3.40889545 2.45708909], vel:[-0.00333499  0.00016839]
# E: -0.08097664171969436
# avgT: 0.0
# avgP: 0.0
#
# time: 0.01
# iterations: 8
#  id:atom1, pos:[1.51111173 2.55291055], vel:[ 0.00384813 -0.0001943 ]
#  id:atom2, pos:[3.40888827 2.45708945], vel:[-0.00384813  0.0001943 ]
# E: -0.08097664171296519
# avgT: 0.0
# avgP: 0.0
#
# time: 0.02
# iterations: 9
#  id:atom1, pos:[1.51111994 2.55291013], vel:[ 0.0043613  -0.00022021]
#  id:atom2, pos:[3.40888006 2.45708987], vel:[-0.0043613   0.00022021]
# E: -0.08097664170527336
# avgT: 0.0
# avgP: 0.0
#
# time: 0.02
# iterations: 10
#  id:atom1, pos:[1.51112918 2.55290967], vel:[ 0.0048745  -0.00024612]
#  id:atom2, pos:[3.40887082 2.45709033], vel:[-0.0048745   0.00024612]
# E: -0.0809766416966184
# avgT: 0.0
# avgP: 0.0
#
# time: 0.02
# iterations: 11
#  id:atom1, pos:[1.51113944 2.55290915], vel:[ 0.00538774 -0.00027203]
#  id:atom2, pos:[3.40886056 2.45709085], vel:[-0.00538774  0.00027203]
# E: -0.08097664168699961
# avgT: 0.0
# avgP: 0.0
#
# time: 0.02
# iterations: 12
#  id:atom1, pos:[1.51115073 2.55290858], vel:[ 0.00590102 -0.00029795]
#  id:atom2, pos:[3.40884927 2.45709142], vel:[-0.00590102  0.00029795]
# E: -0.08097664167641634
# avgT: 0.0
# avgP: 0.0
#
# time: 0.02
# iterations: 13
#  id:atom1, pos:[1.51116304 2.55290796], vel:[ 0.00641434 -0.00032387]
#  id:atom2, pos:[3.40883696 2.45709204], vel:[-0.00641434  0.00032387]
# E: -0.08097664166486793
# avgT: 0.0
# avgP: 0.0
#
# time: 0.03
# iterations: 14
#  id:atom1, pos:[1.51117639 2.55290728], vel:[ 0.0069277  -0.00034979]
#  id:atom2, pos:[3.40882361 2.45709272], vel:[-0.0069277   0.00034979]
# E: -0.08097664165235348
# avgT: 0.0
# avgP: 0.0
#
# time: 0.03
# iterations: 15
#  id:atom1, pos:[1.51119075 2.55290656], vel:[ 0.00744112 -0.00037571]
#  id:atom2, pos:[3.40880925 2.45709344], vel:[-0.00744112  0.00037571]
# E: -0.08097664163887211
# avgT: 0.0
# avgP: 0.0
#
# time: 0.03
# iterations: 16
#  id:atom1, pos:[1.51120615 2.55290578], vel:[ 0.00795459 -0.00040164]
#  id:atom2, pos:[3.40879385 2.45709422], vel:[-0.00795459  0.00040164]
# E: -0.08097664162442303
# avgT: 0.0
# avgP: 0.0
#
# time: 0.03
# iterations: 17
#  id:atom1, pos:[1.51122257 2.55290495], vel:[ 0.00846811 -0.00042757]
#  id:atom2, pos:[3.40877743 2.45709505], vel:[-0.00846811  0.00042757]
# E: -0.08097664160900507
# avgT: 0.0
# avgP: 0.0
#
# time: 0.03
# iterations: 18
#  id:atom1, pos:[1.51124002 2.55290407], vel:[ 0.0089817 -0.0004535]
#  id:atom2, pos:[3.40875998 2.45709593], vel:[-0.0089817  0.0004535]
# E: -0.08097664159261714
# avgT: 0.0
# avgP: 0.0
#
# time: 0.04
# iterations: 19
#  id:atom1, pos:[1.5112585  2.55290314], vel:[ 0.00949536 -0.00047943]
#  id:atom2, pos:[3.4087415  2.45709686], vel:[-0.00949536  0.00047943]
# E: -0.0809766415752583
# avgT: 0.0
# avgP: 0.0
#
# time: 0.04
# iterations: 20
#  id:atom1, pos:[1.511278   2.55290215], vel:[ 0.01000908 -0.00050537]
#  id:atom2, pos:[3.408722   2.45709785], vel:[-0.01000908  0.00050537]
# E: -0.08097664155692719
# avgT: 0.0
# avgP: 0.0
#
# time: 0.04
# iterations: 21
#  id:atom1, pos:[1.51129854 2.55290112], vel:[ 0.01052288 -0.00053131]
#  id:atom2, pos:[3.40870146 2.45709888], vel:[-0.01052288  0.00053131]
# E: -0.08097664153762249
# avgT: 0.0
# avgP: 0.0
#
# time: 0.04
# iterations: 22
#  id:atom1, pos:[1.5113201  2.55290003], vel:[ 0.01103676 -0.00055726]
#  id:atom2, pos:[3.4086799  2.45709997], vel:[-0.01103676  0.00055726]
# E: -0.08097664151734292
# avgT: 0.0
# avgP: 0.0
#
# time: 0.04
# iterations: 23
#  id:atom1, pos:[1.51134268 2.55289889], vel:[ 0.01155071 -0.00058321]
#  id:atom2, pos:[3.40865732 2.45710111], vel:[-0.01155071  0.00058321]
# E: -0.08097664149608706
# avgT: 0.0
# avgP: 0.0
#
# time: 0.05
# iterations: 24
#  id:atom1, pos:[1.5113663 2.5528977], vel:[ 0.01206475 -0.00060916]
#  id:atom2, pos:[3.4086337 2.4571023], vel:[-0.01206475  0.00060916]
# E: -0.08097664147385339
# avgT: 0.0
# avgP: 0.0
#
# time: 0.05
# iterations: 25
#  id:atom1, pos:[1.51139094 2.55289645], vel:[ 0.01257888 -0.00063512]
#  id:atom2, pos:[3.40860906 2.45710355], vel:[-0.01257888  0.00063512]
# E: -0.08097664145064046
# avgT: 0.0
# avgP: 0.0
#
# time: 0.05
# iterations: 26
#  id:atom1, pos:[1.51141661 2.55289516], vel:[ 0.0130931  -0.00066109]
#  id:atom2, pos:[3.40858339 2.45710484], vel:[-0.0130931   0.00066109]
# E: -0.08097664142644655
# avgT: 0.0
# avgP: 0.0
#
# time: 0.05
# iterations: 27
#  id:atom1, pos:[1.51144331 2.55289381], vel:[ 0.01360741 -0.00068706]
#  id:atom2, pos:[3.40855669 2.45710619], vel:[-0.01360741  0.00068706]
# E: -0.08097664140127007
# avgT: 0.0
# avgP: 0.0
#
# time: 0.05
# iterations: 28
#  id:atom1, pos:[1.51147104 2.55289241], vel:[ 0.01412183 -0.00071303]
#  id:atom2, pos:[3.40852896 2.45710759], vel:[-0.01412183  0.00071303]
# E: -0.08097664137510907
# avgT: 0.0
# avgP: 0.0
#
# time: 0.06
# iterations: 29
#  id:atom1, pos:[1.5114998  2.55289096], vel:[ 0.01463634 -0.00073901]
#  id:atom2, pos:[3.4085002  2.45710904], vel:[-0.01463634  0.00073901]
# E: -0.08097664134796191
# avgT: 0.0
# avgP: 0.0
#
# time: 0.06
# iterations: 30
#  id:atom1, pos:[1.51152959 2.55288945], vel:[ 0.01515097 -0.00076499]
#  id:atom2, pos:[3.40847041 2.45711055], vel:[-0.01515097  0.00076499]
# E: -0.0809766413198266
# avgT: 0.0
# avgP: 0.0
#
# time: 0.06
# iterations: 31
#  id:atom1, pos:[1.51156041 2.5528879 ], vel:[ 0.0156657  -0.00079098]
#  id:atom2, pos:[3.40843959 2.4571121 ], vel:[-0.0156657   0.00079098]
# E: -0.08097664129070116
# avgT: 0.0
# avgP: 0.0
#
# time: 0.06
# iterations: 32
#  id:atom1, pos:[1.51159225 2.55288629], vel:[ 0.01618055 -0.00081698]
#  id:atom2, pos:[3.40840775 2.45711371], vel:[-0.01618055  0.00081698]
# E: -0.08097664126058346
# avgT: 0.0
# avgP: 0.0
#
# time: 0.06
# iterations: 33
#  id:atom1, pos:[1.51162513 2.55288463], vel:[ 0.01669552 -0.00084298]
#  id:atom2, pos:[3.40837487 2.45711537], vel:[-0.01669552  0.00084298]
# E: -0.08097664122947158
# avgT: 0.0
# avgP: 0.0
#
# time: 0.07
# iterations: 34
#  id:atom1, pos:[1.51165903 2.55288292], vel:[ 0.01721061 -0.00086899]
#  id:atom2, pos:[3.40834097 2.45711708], vel:[-0.01721061  0.00086899]
# E: -0.08097664119736318
# avgT: 0.0
# avgP: 0.0
#
# time: 0.07
# iterations: 35
#  id:atom1, pos:[1.51169397 2.55288115], vel:[ 0.01772582 -0.000895  ]
#  id:atom2, pos:[3.40830603 2.45711885], vel:[-0.01772582  0.000895  ]
# E: -0.08097664116425611
# avgT: 0.0
# avgP: 0.0
#
# time: 0.07
# iterations: 36
#  id:atom1, pos:[1.51172994 2.55287934], vel:[ 0.01824117 -0.00092102]
#  id:atom2, pos:[3.40827006 2.45712066], vel:[-0.01824117  0.00092102]
# E: -0.08097664113014805
# avgT: 0.0
# avgP: 0.0
#
# time: 0.07
# iterations: 37
#  id:atom1, pos:[1.51176693 2.55287747], vel:[ 0.01875665 -0.00094705]
#  id:atom2, pos:[3.40823307 2.45712253], vel:[-0.01875665  0.00094705]
# E: -0.08097664109503652
# avgT: 0.0
# avgP: 0.0
#
# time: 0.07
# iterations: 38
#  id:atom1, pos:[1.51180496 2.55287555], vel:[ 0.01927226 -0.00097308]
#  id:atom2, pos:[3.40819504 2.45712445], vel:[-0.01927226  0.00097308]
# E: -0.08097664105891916
# avgT: 0.0
# avgP: 0.0
#
# time: 0.08
# iterations: 39
#  id:atom1, pos:[1.51184402 2.55287357], vel:[ 0.01978802 -0.00099912]
#  id:atom2, pos:[3.40815598 2.45712643], vel:[-0.01978802  0.00099912]
# E: -0.08097664102179333
# avgT: 0.0
# avgP: 0.0
#
# time: 0.08
# iterations: 40
#  id:atom1, pos:[1.51188412 2.55287155], vel:[ 0.02030392 -0.00102517]
#  id:atom2, pos:[3.40811588 2.45712845], vel:[-0.02030392  0.00102517]
# E: -0.08097664098365648
# avgT: 0.0
# avgP: 0.0
#
# time: 0.08
# iterations: 41
#  id:atom1, pos:[1.51192524 2.55286947], vel:[ 0.02081997 -0.00105123]
#  id:atom2, pos:[3.40807476 2.45713053], vel:[-0.02081997  0.00105123]
# E: -0.08097664094450584
# avgT: 0.0
# avgP: 0.0
#
# time: 0.08
# iterations: 42
#  id:atom1, pos:[1.5119674  2.55286735], vel:[ 0.02133618 -0.00107729]
#  id:atom2, pos:[3.4080326  2.45713265], vel:[-0.02133618  0.00107729]
# E: -0.08097664090433869
# avgT: 0.0
# avgP: 0.0
#
# time: 0.08
# iterations: 43
#  id:atom1, pos:[1.51201058 2.55286517], vel:[ 0.02185254 -0.00110336]
#  id:atom2, pos:[3.40798942 2.45713483], vel:[-0.02185254  0.00110336]
# E: -0.08097664086315225
# avgT: 0.0
# avgP: 0.0
#
# time: 0.09
# iterations: 44
#  id:atom1, pos:[1.51205481 2.55286293], vel:[ 0.02236906 -0.00112944]
#  id:atom2, pos:[3.40794519 2.45713707], vel:[-0.02236906  0.00112944]
# E: -0.08097664082094348
# avgT: 0.0
# avgP: 0.0
#
# time: 0.09
# iterations: 45
#  id:atom1, pos:[1.51210006 2.55286065], vel:[ 0.02288574 -0.00115553]
#  id:atom2, pos:[3.40789994 2.45713935], vel:[-0.02288574  0.00115553]
# E: -0.08097664077770952
# avgT: 0.0
# avgP: 0.0
#
# time: 0.09
# iterations: 46
#  id:atom1, pos:[1.51214635 2.55285831], vel:[ 0.02340259 -0.00118163]
#  id:atom2, pos:[3.40785365 2.45714169], vel:[-0.02340259  0.00118163]
# E: -0.08097664073344729
# avgT: 0.0
# avgP: 0.0
#
# time: 0.09
# iterations: 47
#  id:atom1, pos:[1.51219367 2.55285592], vel:[ 0.02391962 -0.00120773]
#  id:atom2, pos:[3.40780633 2.45714408], vel:[-0.02391962  0.00120773]
# E: -0.08097664068815363
# avgT: 0.0
# avgP: 0.0
#
# time: 0.09
# iterations: 48
#  id:atom1, pos:[1.51224203 2.55285348], vel:[ 0.02443682 -0.00123385]
#  id:atom2, pos:[3.40775797 2.45714652], vel:[-0.02443682  0.00123385]
# E: -0.08097664064182532
# avgT: 0.0
# avgP: 0.0
#
# time: 0.10
# iterations: 49
#  id:atom1, pos:[1.51229142 2.55285099], vel:[ 0.0249542  -0.00125997]
#  id:atom2, pos:[3.40770858 2.45714901], vel:[-0.0249542   0.00125997]
# E: -0.08097664059445922
# avgT: 0.0
# avgP: 0.0
#
# time: 0.10
# iterations: 50
#  id:atom1, pos:[1.51234184 2.55284844], vel:[ 0.02547176 -0.0012861 ]
#  id:atom2, pos:[3.40765816 2.45715156], vel:[-0.02547176  0.0012861 ]
# E: -0.08097664054605175
# avgT: 0.0
# avgP: 0.0
#
# time: 0.10
# iterations: 51
#  id:atom1, pos:[1.5123933  2.55284584], vel:[ 0.02598951 -0.00131224]
#  id:atom2, pos:[3.4076067  2.45715416], vel:[-0.02598951  0.00131224]
# E: -0.08097664049659963
# avgT: 0.0
# avgP: 0.0
#
# time: 0.10
# iterations: 52
#  id:atom1, pos:[1.5124458  2.55284319], vel:[ 0.02650745 -0.00133839]
#  id:atom2, pos:[3.4075542  2.45715681], vel:[-0.02650745  0.00133839]
# E: -0.08097664044609933
# avgT: 0.0
# avgP: 0.0
#
# time: 0.10
# iterations: 53
#  id:atom1, pos:[1.51249933 2.55284049], vel:[ 0.02702559 -0.00136456]
#  id:atom2, pos:[3.40750067 2.45715951], vel:[-0.02702559  0.00136456]
# E: -0.08097664039454729
# avgT: 0.0
# avgP: 0.0
#
# time: 0.11
# iterations: 54
#  id:atom1, pos:[1.5125539  2.55283773], vel:[ 0.02754393 -0.00139073]
#  id:atom2, pos:[3.4074461  2.45716227], vel:[-0.02754393  0.00139073]
# E: -0.0809766403419397
# avgT: 0.0
# avgP: 0.0
#
# time: 0.11
# iterations: 55
#  id:atom1, pos:[1.51260951 2.55283492], vel:[ 0.02806246 -0.00141691]
#  id:atom2, pos:[3.40739049 2.45716508], vel:[-0.02806246  0.00141691]
# E: -0.08097664028827291
# avgT: 0.0
# avgP: 0.0
#
# time: 0.11
# iterations: 56
#  id:atom1, pos:[1.51266615 2.55283206], vel:[ 0.02858121 -0.0014431 ]
#  id:atom2, pos:[3.40733385 2.45716794], vel:[-0.02858121  0.0014431 ]
# E: -0.08097664023354315
# avgT: 0.0
# avgP: 0.0
#
# time: 0.11
# iterations: 57
#  id:atom1, pos:[1.51272384 2.55282915], vel:[ 0.02910016 -0.0014693 ]
#  id:atom2, pos:[3.40727616 2.45717085], vel:[-0.02910016  0.0014693 ]
# E: -0.08097664017774639
# avgT: 0.0
# avgP: 0.0
#
# time: 0.11
# iterations: 58
#  id:atom1, pos:[1.51278255 2.55282619], vel:[ 0.02961934 -0.00149552]
#  id:atom2, pos:[3.40721745 2.45717381], vel:[-0.02961934  0.00149552]
# E: -0.08097664012087877
# avgT: 0.0
# avgP: 0.0
#
# time: 0.12
# iterations: 59
#  id:atom1, pos:[1.51284231 2.55282317], vel:[ 0.03013872 -0.00152174]
#  id:atom2, pos:[3.40715769 2.45717683], vel:[-0.03013872  0.00152174]
# E: -0.08097664006293619
# avgT: 0.0
# avgP: 0.0
#
# time: 0.12
# iterations: 60
#  id:atom1, pos:[1.51290311 2.5528201 ], vel:[ 0.03065834 -0.00154798]
#  id:atom2, pos:[3.40709689 2.4571799 ], vel:[-0.03065834  0.00154798]
# E: -0.08097664000391445
# avgT: 0.0
# avgP: 0.0
#
# time: 0.12
# iterations: 61
#  id:atom1, pos:[1.51296495 2.55281698], vel:[ 0.03117818 -0.00157422]
#  id:atom2, pos:[3.40703505 2.45718302], vel:[-0.03117818  0.00157422]
# E: -0.08097663994380931
# avgT: 0.0
# avgP: 0.0
#
# time: 0.12
# iterations: 62
#  id:atom1, pos:[1.51302782 2.5528138 ], vel:[ 0.03169824 -0.00160048]
#  id:atom2, pos:[3.40697218 2.4571862 ], vel:[-0.03169824  0.00160048]
# E: -0.08097663988261662
# avgT: 0.0
# avgP: 0.0
#
# time: 0.12
# iterations: 63
#  id:atom1, pos:[1.51309174 2.55281058], vel:[ 0.03221855 -0.00162675]
#  id:atom2, pos:[3.40690826 2.45718942], vel:[-0.03221855  0.00162675]
# E: -0.08097663982033182
# avgT: 0.0
# avgP: 0.0
#
# time: 0.13
# iterations: 64
#  id:atom1, pos:[1.5131567 2.5528073], vel:[ 0.03273909 -0.00165304]
#  id:atom2, pos:[3.4068433 2.4571927], vel:[-0.03273909  0.00165304]
# E: -0.08097663975695052
# avgT: 0.0
# avgP: 0.0
#
# time: 0.13
# iterations: 65
#  id:atom1, pos:[1.5132227  2.55280396], vel:[ 0.03325987 -0.00167933]
#  id:atom2, pos:[3.4067773  2.45719604], vel:[-0.03325987  0.00167933]
# E: -0.08097663969246807
# avgT: 0.0
# avgP: 0.0
#
# time: 0.13
# iterations: 66
#  id:atom1, pos:[1.51328974 2.55280058], vel:[ 0.0337809  -0.00170564]
#  id:atom2, pos:[3.40671026 2.45719942], vel:[-0.0337809   0.00170564]
# E: -0.08097663962688008
# avgT: 0.0
# avgP: 0.0
#
# time: 0.13
# iterations: 67
#  id:atom1, pos:[1.51335782 2.55279714], vel:[ 0.03430218 -0.00173196]
#  id:atom2, pos:[3.40664218 2.45720286], vel:[-0.03430218  0.00173196]
# E: -0.0809766395601816
# avgT: 0.0
# avgP: 0.0
#
# time: 0.13
# iterations: 68
#  id:atom1, pos:[1.51342694 2.55279365], vel:[ 0.03482372 -0.00175829]
#  id:atom2, pos:[3.40657306 2.45720635], vel:[-0.03482372  0.00175829]
# E: -0.08097663949236794
# avgT: 0.0
# avgP: 0.0
#
# time: 0.14
# iterations: 69
#  id:atom1, pos:[1.51349711 2.55279011], vel:[ 0.03534551 -0.00178464]
#  id:atom2, pos:[3.40650289 2.45720989], vel:[-0.03534551  0.00178464]
# E: -0.08097663942343418
# avgT: 0.0
# avgP: 0.0
#
# time: 0.14
# iterations: 70
#  id:atom1, pos:[1.51356833 2.55278651], vel:[ 0.03586757 -0.001811  ]
#  id:atom2, pos:[3.40643167 2.45721349], vel:[-0.03586757  0.001811  ]
# E: -0.08097663935337528
# avgT: 0.0
# avgP: 0.0
#
# time: 0.14
# iterations: 71
#  id:atom1, pos:[1.51364058 2.55278286], vel:[ 0.03638989 -0.00183737]
#  id:atom2, pos:[3.40635942 2.45721714], vel:[-0.03638989  0.00183737]
# E: -0.08097663928218622
# avgT: 0.0
# avgP: 0.0
#
# time: 0.14
# iterations: 72
#  id:atom1, pos:[1.51371389 2.55277916], vel:[ 0.03691248 -0.00186376]
#  id:atom2, pos:[3.40628611 2.45722084], vel:[-0.03691248  0.00186376]
# E: -0.08097663920986184
# avgT: 0.0
# avgP: 0.0
#
# time: 0.14
# iterations: 73
#  id:atom1, pos:[1.51378823 2.55277541], vel:[ 0.03743535 -0.00189016]
#  id:atom2, pos:[3.40621177 2.45722459], vel:[-0.03743535  0.00189016]
# E: -0.0809766391363969
# avgT: 0.0
# avgP: 0.0
#
# time: 0.15
# iterations: 74
#  id:atom1, pos:[1.51386363 2.5527716 ], vel:[ 0.03795849 -0.00191657]
#  id:atom2, pos:[3.40613637 2.4572284 ], vel:[-0.03795849  0.00191657]
# E: -0.0809766390617861
# avgT: 0.0
# avgP: 0.0
#
# time: 0.15
# iterations: 75
#  id:atom1, pos:[1.51394007 2.55276774], vel:[ 0.03848192 -0.001943  ]
#  id:atom2, pos:[3.40605993 2.45723226], vel:[-0.03848192  0.001943  ]
# E: -0.08097663898602397
# avgT: 0.0
# avgP: 0.0
#
# time: 0.15
# iterations: 76
#  id:atom1, pos:[1.51401756 2.55276383], vel:[ 0.03900563 -0.00196944]
#  id:atom2, pos:[3.40598244 2.45723617], vel:[-0.03900563  0.00196944]
# E: -0.08097663890910517
# avgT: 0.0
# avgP: 0.0
#
# time: 0.15
# iterations: 77
#  id:atom1, pos:[1.51409609 2.55275987], vel:[ 0.03952964 -0.0019959 ]
#  id:atom2, pos:[3.40590391 2.45724013], vel:[-0.03952964  0.0019959 ]
# E: -0.08097663883102393
# avgT: 0.0
# avgP: 0.0
#
# time: 0.15
# iterations: 78
#  id:atom1, pos:[1.51417567 2.55275585], vel:[ 0.04005394 -0.00202237]
#  id:atom2, pos:[3.40582433 2.45724415], vel:[-0.04005394  0.00202237]
# E: -0.08097663875177459
# avgT: 0.0
# avgP: 0.0
#
# time: 0.16
# iterations: 79
#  id:atom1, pos:[1.51425631 2.55275178], vel:[ 0.04057854 -0.00204886]
#  id:atom2, pos:[3.40574369 2.45724822], vel:[-0.04057854  0.00204886]
# E: -0.08097663867135133
# avgT: 0.0
# avgP: 0.0
#
# time: 0.16
# iterations: 80
#  id:atom1, pos:[1.51433799 2.55274765], vel:[ 0.04110344 -0.00207536]
#  id:atom2, pos:[3.40566201 2.45725235], vel:[-0.04110344  0.00207536]
# E: -0.08097663858974831
# avgT: 0.0
# avgP: 0.0
#
# time: 0.16
# iterations: 81
#  id:atom1, pos:[1.51442072 2.55274347], vel:[ 0.04162864 -0.00210188]
#  id:atom2, pos:[3.40557928 2.45725653], vel:[-0.04162864  0.00210188]
# E: -0.08097663850695963
# avgT: 0.0
# avgP: 0.0
#
# time: 0.16
# iterations: 82
#  id:atom1, pos:[1.5145045  2.55273924], vel:[ 0.04215416 -0.00212842]
#  id:atom2, pos:[3.4054955  2.45726076], vel:[-0.04215416  0.00212842]
# E: -0.08097663842297916
# avgT: 0.0
# avgP: 0.0
#
# time: 0.16
# iterations: 83
#  id:atom1, pos:[1.51458934 2.55273496], vel:[ 0.04268    -0.00215497]
#  id:atom2, pos:[3.40541066 2.45726504], vel:[-0.04268     0.00215497]
# E: -0.08097663833780076
# avgT: 0.0
# avgP: 0.0
#
# time: 0.17
# iterations: 84
#  id:atom1, pos:[1.51467522 2.55273062], vel:[ 0.04320615 -0.00218153]
#  id:atom2, pos:[3.40532478 2.45726938], vel:[-0.04320615  0.00218153]
# E: -0.08097663825141815
# avgT: 0.0
# avgP: 0.0
#
# time: 0.17
# iterations: 85
#  id:atom1, pos:[1.51476216 2.55272623], vel:[ 0.04373263 -0.00220812]
#  id:atom2, pos:[3.40523784 2.45727377], vel:[-0.04373263  0.00220812]
# E: -0.08097663816382494
# avgT: 0.0
# avgP: 0.0
#
# time: 0.17
# iterations: 86
#  id:atom1, pos:[1.51485015 2.55272179], vel:[ 0.04425944 -0.00223471]
#  id:atom2, pos:[3.40514985 2.45727821], vel:[-0.04425944  0.00223471]
# E: -0.08097663807501476
# avgT: 0.0
# avgP: 0.0
#
# time: 0.17
# iterations: 87
#  id:atom1, pos:[1.5149392 2.5527173], vel:[ 0.04478658 -0.00226133]
#  id:atom2, pos:[3.4050608 2.4572827], vel:[-0.04478658  0.00226133]
# E: -0.0809766379849811
# avgT: 0.0
# avgP: 0.0
#
# time: 0.17
# iterations: 88
#  id:atom1, pos:[1.5150293  2.55271275], vel:[ 0.04531405 -0.00228796]
#  id:atom2, pos:[3.4049707  2.45728725], vel:[-0.04531405  0.00228796]
# E: -0.08097663789371719
# avgT: 0.0
# avgP: 0.0
#
# time: 0.18
# iterations: 89
#  id:atom1, pos:[1.51512046 2.55270814], vel:[ 0.04584187 -0.00231461]
#  id:atom2, pos:[3.40487954 2.45729186], vel:[-0.04584187  0.00231461]
# E: -0.08097663780121633
# avgT: 0.0
# avgP: 0.0
#
# time: 0.18
# iterations: 90
#  id:atom1, pos:[1.51521267 2.55270349], vel:[ 0.04637002 -0.00234128]
#  id:atom2, pos:[3.40478733 2.45729651], vel:[-0.04637002  0.00234128]
# E: -0.08097663770747186
# avgT: 0.0
# avgP: 0.0
#
# time: 0.18
# iterations: 91
#  id:atom1, pos:[1.51530594 2.55269878], vel:[ 0.04689853 -0.00236797]
#  id:atom2, pos:[3.40469406 2.45730122], vel:[-0.04689853  0.00236797]
# E: -0.08097663761247659
# avgT: 0.0
# avgP: 0.0
#
# time: 0.18
# iterations: 92
#  id:atom1, pos:[1.51540026 2.55269402], vel:[ 0.04742739 -0.00239467]
#  id:atom2, pos:[3.40459974 2.45730598], vel:[-0.04742739  0.00239467]
# E: -0.0809766375162236
# avgT: 0.0
# avgP: 0.0
#
# time: 0.18
# iterations: 93
#  id:atom1, pos:[1.51549564 2.5526892 ], vel:[ 0.04795661 -0.00242139]
#  id:atom2, pos:[3.40450436 2.4573108 ], vel:[-0.04795661  0.00242139]
# E: -0.0809766374187056
# avgT: 0.0
# avgP: 0.0
#
# time: 0.19
# iterations: 94
#  id:atom1, pos:[1.51559209 2.55268433], vel:[ 0.04848619 -0.00244813]
#  id:atom2, pos:[3.40440791 2.45731567], vel:[-0.04848619  0.00244813]
# E: -0.08097663731991558
# avgT: 0.0
# avgP: 0.0
#
# time: 0.19
# iterations: 95
#  id:atom1, pos:[1.51568959 2.55267941], vel:[ 0.04901614 -0.00247489]
#  id:atom2, pos:[3.40431041 2.45732059], vel:[-0.04901614  0.00247489]
# E: -0.08097663721984591
# avgT: 0.0
# avgP: 0.0
#
# time: 0.19
# iterations: 96
#  id:atom1, pos:[1.51578815 2.55267443], vel:[ 0.04954645 -0.00250166]
#  id:atom2, pos:[3.40421185 2.45732557], vel:[-0.04954645  0.00250166]
# E: -0.08097663711848929
# avgT: 0.0
# avgP: 0.0
#
# time: 0.19
# iterations: 97
#  id:atom1, pos:[1.51588778 2.5526694 ], vel:[ 0.05007714 -0.00252846]
#  id:atom2, pos:[3.40411222 2.4573306 ], vel:[-0.05007714  0.00252846]
# E: -0.08097663701583806
# avgT: 0.0
# avgP: 0.0
#
# time: 0.19
# iterations: 98
#  id:atom1, pos:[1.51598846 2.55266432], vel:[ 0.05060821 -0.00255527]
#  id:atom2, pos:[3.40401154 2.45733568], vel:[-0.05060821  0.00255527]
# E: -0.08097663691188456
# avgT: 0.0
# avgP: 0.0
#
# time: 0.20
# iterations: 99
#  id:atom1, pos:[1.51609021 2.55265918], vel:[ 0.05113967 -0.00258211]
#  id:atom2, pos:[3.40390979 2.45734082], vel:[-0.05113967  0.00258211]
# E: -0.080976636806621
# avgT: 0.0
# avgP: 0.0
#
# time: 0.20
# iterations: 100
#  id:atom1, pos:[1.51619302 2.55265399], vel:[ 0.05167151 -0.00260896]
#  id:atom2, pos:[3.40380698 2.45734601], vel:[-0.05167151  0.00260896]
# E: -0.08097663670003953
# avgT: 0.0
# avgP: 0.0
#
# time: 0.20
# iterations: 101
#  id:atom1, pos:[1.51629689 2.55264874], vel:[ 0.05220374 -0.00263583]
#  id:atom2, pos:[3.40370311 2.45735126], vel:[-0.05220374  0.00263583]
# E: -0.08097663659213204
# avgT: 0.0
# avgP: 0.0
#
# time: 0.20
# iterations: 102
#  id:atom1, pos:[1.51640183 2.55264345], vel:[ 0.05273637 -0.00266272]
#  id:atom2, pos:[3.40359817 2.45735655], vel:[-0.05273637  0.00266272]
# E: -0.08097663648289047
# avgT: 0.0
# avgP: 0.0
#
# time: 0.20
# iterations: 103
#  id:atom1, pos:[1.51650784 2.55263809], vel:[ 0.05326939 -0.00268964]
#  id:atom2, pos:[3.40349216 2.45736191], vel:[-0.05326939  0.00268964]
# E: -0.08097663637230648
# avgT: 0.0
# avgP: 0.0
#
# time: 0.21
# iterations: 104
#  id:atom1, pos:[1.51661491 2.55263269], vel:[ 0.05380283 -0.00271657]
#  id:atom2, pos:[3.40338509 2.45736731], vel:[-0.05380283  0.00271657]
# E: -0.08097663626037194
# avgT: 0.0
# avgP: 0.0
#
# time: 0.21
# iterations: 105
#  id:atom1, pos:[1.51672305 2.55262723], vel:[ 0.05433667 -0.00274353]
#  id:atom2, pos:[3.40327695 2.45737277], vel:[-0.05433667  0.00274353]
# E: -0.08097663614707819
# avgT: 0.0
# avgP: 0.0
#
# time: 0.21
# iterations: 106
#  id:atom1, pos:[1.51683226 2.55262171], vel:[ 0.05487092 -0.0027705 ]
#  id:atom2, pos:[3.40316774 2.45737829], vel:[-0.05487092  0.0027705 ]
# E: -0.08097663603241666
# avgT: 0.0
# avgP: 0.0
#
# time: 0.21
# iterations: 107
#  id:atom1, pos:[1.51694253 2.55261614], vel:[ 0.0554056 -0.0027975]
#  id:atom2, pos:[3.40305747 2.45738386], vel:[-0.0554056  0.0027975]
# E: -0.08097663591637878
# avgT: 0.0
# avgP: 0.0
#
# time: 0.21
# iterations: 108
#  id:atom1, pos:[1.51705388 2.55261052], vel:[ 0.0559407  -0.00282452]
#  id:atom2, pos:[3.40294612 2.45738948], vel:[-0.0559407   0.00282452]
# E: -0.08097663579895552
# avgT: 0.0
# avgP: 0.0
#
# time: 0.22
# iterations: 109
#  id:atom1, pos:[1.5171663  2.55260485], vel:[ 0.05647622 -0.00285155]
#  id:atom2, pos:[3.4028337  2.45739515], vel:[-0.05647622  0.00285155]
# E: -0.08097663568013808
# avgT: 0.0
# avgP: 0.0
#
# time: 0.22
# iterations: 110
#  id:atom1, pos:[1.51727979 2.55259912], vel:[ 0.05701217 -0.00287862]
#  id:atom2, pos:[3.40272021 2.45740088], vel:[-0.05701217  0.00287862]
# E: -0.08097663555991737
# avgT: 0.0
# avgP: 0.0
#
# time: 0.22
# iterations: 111
#  id:atom1, pos:[1.51739435 2.55259333], vel:[ 0.05754857 -0.0029057 ]
#  id:atom2, pos:[3.40260565 2.45740667], vel:[-0.05754857  0.0029057 ]
# E: -0.08097663543828414
# avgT: 0.0
# avgP: 0.0
#
# time: 0.22
# iterations: 112
#  id:atom1, pos:[1.51750998 2.55258749], vel:[ 0.0580854 -0.0029328]
#  id:atom2, pos:[3.40249002 2.45741251], vel:[-0.0580854  0.0029328]
# E: -0.0809766353152292
# avgT: 0.0
# avgP: 0.0
#
# time: 0.22
# iterations: 113
#  id:atom1, pos:[1.51762669 2.5525816 ], vel:[ 0.05862267 -0.00295993]
#  id:atom2, pos:[3.40237331 2.4574184 ], vel:[-0.05862267  0.00295993]
# E: -0.08097663519074302
# avgT: 0.0
# avgP: 0.0
#
# time: 0.23
# iterations: 114
#  id:atom1, pos:[1.51774447 2.55257565], vel:[ 0.0591604  -0.00298708]
#  id:atom2, pos:[3.40225553 2.45742435], vel:[-0.0591604   0.00298708]
# E: -0.08097663506481613
# avgT: 0.0
# avgP: 0.0
#
# time: 0.23
# iterations: 115
#  id:atom1, pos:[1.51786333 2.55256965], vel:[ 0.05969858 -0.00301426]
#  id:atom2, pos:[3.40213667 2.45743035], vel:[-0.05969858  0.00301426]
# E: -0.08097663493743872
# avgT: 0.0
# avgP: 0.0
#
# time: 0.23
# iterations: 116
#  id:atom1, pos:[1.51798326 2.5525636 ], vel:[ 0.06023722 -0.00304145]
#  id:atom2, pos:[3.40201674 2.4574364 ], vel:[-0.06023722  0.00304145]
# E: -0.08097663480860114
# avgT: 0.0
# avgP: 0.0
#
# time: 0.23
# iterations: 117
#  id:atom1, pos:[1.51810428 2.55255749], vel:[ 0.06077632 -0.00306867]
#  id:atom2, pos:[3.40189572 2.45744251], vel:[-0.06077632  0.00306867]
# E: -0.08097663467829332
# avgT: 0.0
# avgP: 0.0
#
# time: 0.23
# iterations: 118
#  id:atom1, pos:[1.51822637 2.55255132], vel:[ 0.06131589 -0.00309592]
#  id:atom2, pos:[3.40177363 2.45744868], vel:[-0.06131589  0.00309592]
# E: -0.08097663454650521
# avgT: 0.0
# avgP: 0.0
#
# time: 0.24
# iterations: 119
#  id:atom1, pos:[1.51834954 2.5525451 ], vel:[ 0.06185593 -0.00312318]
#  id:atom2, pos:[3.40165046 2.4574549 ], vel:[-0.06185593  0.00312318]
# E: -0.0809766344132266
# avgT: 0.0
# avgP: 0.0
#
# time: 0.24
# iterations: 120
#  id:atom1, pos:[1.51847379 2.55253883], vel:[ 0.06239645 -0.00315047]
#  id:atom2, pos:[3.40152621 2.45746117], vel:[-0.06239645  0.00315047]
# E: -0.08097663427844719
# avgT: 0.0
# avgP: 0.0
#
# time: 0.24
# iterations: 121
#  id:atom1, pos:[1.51859913 2.5525325 ], vel:[ 0.06293745 -0.00317779]
#  id:atom2, pos:[3.40140087 2.4574675 ], vel:[-0.06293745  0.00317779]
# E: -0.0809766341421564
# avgT: 0.0
# avgP: 0.0
#
# time: 0.24
# iterations: 122
#  id:atom1, pos:[1.51872554 2.55252612], vel:[ 0.06347894 -0.00320513]
#  id:atom2, pos:[3.40127446 2.45747388], vel:[-0.06347894  0.00320513]
# E: -0.08097663400434364
# avgT: 0.0
# avgP: 0.0
#
# time: 0.24
# iterations: 123
#  id:atom1, pos:[1.51885304 2.55251968], vel:[ 0.06402092 -0.0032325 ]
#  id:atom2, pos:[3.40114696 2.45748032], vel:[-0.06402092  0.0032325 ]
# E: -0.08097663386499825
# avgT: 0.0
# avgP: 0.0
#
# time: 0.25
# iterations: 124
#  id:atom1, pos:[1.51898163 2.55251319], vel:[ 0.06456339 -0.00325989]
#  id:atom2, pos:[3.40101837 2.45748681], vel:[-0.06456339  0.00325989]
# E: -0.0809766337241093
# avgT: 0.0
# avgP: 0.0
#
# time: 0.25
# iterations: 125
#  id:atom1, pos:[1.5191113  2.55250664], vel:[ 0.06510637 -0.0032873 ]
#  id:atom2, pos:[3.4008887  2.45749336], vel:[-0.06510637  0.0032873 ]
# E: -0.08097663358166568
# avgT: 0.0
# avgP: 0.0
#
# time: 0.25
# iterations: 126
#  id:atom1, pos:[1.51924205 2.55250004], vel:[ 0.06564985 -0.00331474]
#  id:atom2, pos:[3.40075795 2.45749996], vel:[-0.06564985  0.00331474]
# E: -0.08097663343765629
# avgT: 0.0
# avgP: 0.0
#
# time: 0.25
# iterations: 127
#  id:atom1, pos:[1.5193739  2.55249338], vel:[ 0.06619384 -0.00334221]
#  id:atom2, pos:[3.4006261  2.45750662], vel:[-0.06619384  0.00334221]
# E: -0.08097663329206982
# avgT: 0.0
# avgP: 0.0
#
# time: 0.25
# iterations: 128
#  id:atom1, pos:[1.51950683 2.55248667], vel:[ 0.06673834 -0.0033697 ]
#  id:atom2, pos:[3.40049317 2.45751333], vel:[-0.06673834  0.0033697 ]
# E: -0.08097663314489473
# avgT: 0.0
# avgP: 0.0
#
# time: 0.26
# iterations: 129
#  id:atom1, pos:[1.51964085 2.5524799 ], vel:[ 0.06728336 -0.00339722]
#  id:atom2, pos:[3.40035915 2.4575201 ], vel:[-0.06728336  0.00339722]
# E: -0.08097663299611937
# avgT: 0.0
# avgP: 0.0
#
# time: 0.26
# iterations: 130
#  id:atom1, pos:[1.51977596 2.55247308], vel:[ 0.06782891 -0.00342477]
#  id:atom2, pos:[3.40022404 2.45752692], vel:[-0.06782891  0.00342477]
# E: -0.08097663284573221
# avgT: 0.0
# avgP: 0.0
#
# time: 0.26
# iterations: 131
#  id:atom1, pos:[1.51991217 2.5524662 ], vel:[ 0.06837499 -0.00345234]
#  id:atom2, pos:[3.40008783 2.4575338 ], vel:[-0.06837499  0.00345234]
# E: -0.0809766326937211
# avgT: 0.0
# avgP: 0.0
#
# time: 0.26
# iterations: 132
#  id:atom1, pos:[1.52004946 2.55245927], vel:[ 0.0689216  -0.00347994]
#  id:atom2, pos:[3.39995054 2.45754073], vel:[-0.0689216   0.00347994]
# E: -0.08097663254007409
# avgT: 0.0
# avgP: 0.0
#
# time: 0.26
# iterations: 133
#  id:atom1, pos:[1.52018785 2.55245228], vel:[ 0.06946875 -0.00350756]
#  id:atom2, pos:[3.39981215 2.45754772], vel:[-0.06946875  0.00350756]
# E: -0.08097663238477894
# avgT: 0.0
# avgP: 0.0
#
# time: 0.27
# iterations: 134
#  id:atom1, pos:[1.52032734 2.55244524], vel:[ 0.07001644 -0.00353522]
#  id:atom2, pos:[3.39967266 2.45755476], vel:[-0.07001644  0.00353522]
# E: -0.08097663222782318
# avgT: 0.0
# avgP: 0.0
#
# time: 0.27
# iterations: 135
#  id:atom1, pos:[1.52046792 2.55243814], vel:[ 0.07056468 -0.0035629 ]
#  id:atom2, pos:[3.39953208 2.45756186], vel:[-0.07056468  0.0035629 ]
# E: -0.08097663206919442
# avgT: 0.0
# avgP: 0.0
#
# time: 0.27
# iterations: 136
#  id:atom1, pos:[1.5206096  2.55243099], vel:[ 0.07111348 -0.00359061]
#  id:atom2, pos:[3.3993904  2.45756901], vel:[-0.07111348  0.00359061]
# E: -0.08097663190887996
# avgT: 0.0
# avgP: 0.0
#
# time: 0.27
# iterations: 137
#  id:atom1, pos:[1.52075237 2.55242378], vel:[ 0.07166283 -0.00361835]
#  id:atom2, pos:[3.39924763 2.45757622], vel:[-0.07166283  0.00361835]
# E: -0.0809766317468668
# avgT: 0.0
# avgP: 0.0
#
# time: 0.27
# iterations: 138
#  id:atom1, pos:[1.52089625 2.55241652], vel:[ 0.07221275 -0.00364611]
#  id:atom2, pos:[3.39910375 2.45758348], vel:[-0.07221275  0.00364611]
# E: -0.08097663158314208
# avgT: 0.0
# avgP: 0.0
#
# time: 0.28
# iterations: 139
#  id:atom1, pos:[1.52104122 2.5524092 ], vel:[ 0.07276323 -0.00367391]
#  id:atom2, pos:[3.39895878 2.4575908 ], vel:[-0.07276323  0.00367391]
# E: -0.08097663141769251
# avgT: 0.0
# avgP: 0.0
#
# time: 0.28
# iterations: 140
#  id:atom1, pos:[1.5211873  2.55240182], vel:[ 0.07331429 -0.00370173]
#  id:atom2, pos:[3.3988127  2.45759818], vel:[-0.07331429  0.00370173]
# E: -0.08097663125050483
# avgT: 0.0
# avgP: 0.0
#
# time: 0.28
# iterations: 141
#  id:atom1, pos:[1.52133448 2.55239439], vel:[ 0.07386593 -0.00372958]
#  id:atom2, pos:[3.39866552 2.45760561], vel:[-0.07386593  0.00372958]
# E: -0.08097663108156548
# avgT: 0.0
# avgP: 0.0
#
# time: 0.28
# iterations: 142
#  id:atom1, pos:[1.52148276 2.5523869 ], vel:[ 0.07441815 -0.00375746]
#  id:atom2, pos:[3.39851724 2.4576131 ], vel:[-0.07441815  0.00375746]
# E: -0.08097663091086081
# avgT: 0.0
# avgP: 0.0
#
# time: 0.28
# iterations: 143
#  id:atom1, pos:[1.52163215 2.55237936], vel:[ 0.07497096 -0.00378538]
#  id:atom2, pos:[3.39836785 2.45762064], vel:[-0.07497096  0.00378538]
# E: -0.08097663073837699
# avgT: 0.0
# avgP: 0.0
#
# time: 0.29
# iterations: 144
#  id:atom1, pos:[1.52178265 2.55237176], vel:[ 0.07552436 -0.00381332]
#  id:atom2, pos:[3.39821735 2.45762824], vel:[-0.07552436  0.00381332]
# E: -0.08097663056409987
# avgT: 0.0
# avgP: 0.0
#
# time: 0.29
# iterations: 145
#  id:atom1, pos:[1.52193425 2.55236411], vel:[ 0.07607836 -0.00384129]
#  id:atom2, pos:[3.39806575 2.45763589], vel:[-0.07607836  0.00384129]
# E: -0.08097663038801545
# avgT: 0.0
# avgP: 0.0
#
# time: 0.29
# iterations: 146
#  id:atom1, pos:[1.52208696 2.5523564 ], vel:[ 0.07663296 -0.00386929]
#  id:atom2, pos:[3.39791304 2.4576436 ], vel:[-0.07663296  0.00386929]
# E: -0.08097663021010904
# avgT: 0.0
# avgP: 0.0
#
# time: 0.29
# iterations: 147
#  id:atom1, pos:[1.52224078 2.55234863], vel:[ 0.07718817 -0.00389733]
#  id:atom2, pos:[3.39775922 2.45765137], vel:[-0.07718817  0.00389733]
# E: -0.08097663003036636
# avgT: 0.0
# avgP: 0.0
#
# time: 0.29
# iterations: 148
#  id:atom1, pos:[1.52239571 2.55234081], vel:[ 0.077744   -0.00392539]
#  id:atom2, pos:[3.39760429 2.45765919], vel:[-0.077744    0.00392539]
# E: -0.08097662984877259
# avgT: 0.0
# avgP: 0.0
#
# time: 0.30
# iterations: 149
#  id:atom1, pos:[1.52255176 2.55233293], vel:[ 0.07830045 -0.00395349]
#  id:atom2, pos:[3.39744824 2.45766707], vel:[-0.07830045  0.00395349]
# E: -0.08097662966531269
# avgT: 0.0
# avgP: 0.0
#
# time: 0.30
# iterations: 150
#  id:atom1, pos:[1.52270892 2.55232499], vel:[ 0.07885752 -0.00398161]
#  id:atom2, pos:[3.39729108 2.45767501], vel:[-0.07885752  0.00398161]
# E: -0.08097662947997165
# avgT: 0.0
# avgP: 0.0
#
# time: 0.30
# iterations: 151
#  id:atom1, pos:[1.52286719 2.552317  ], vel:[ 0.07941521 -0.00400977]
#  id:atom2, pos:[3.39713281 2.457683  ], vel:[-0.07941521  0.00400977]
# E: -0.08097662929273408
# avgT: 0.0
# avgP: 0.0
#
# time: 0.30
# iterations: 152
#  id:atom1, pos:[1.52302658 2.55230895], vel:[ 0.07997355 -0.00403796]
#  id:atom2, pos:[3.39697342 2.45769105], vel:[-0.07997355  0.00403796]
# E: -0.08097662910358461
# avgT: 0.0
# avgP: 0.0
#
# time: 0.30
# iterations: 153
#  id:atom1, pos:[1.52318708 2.55230085], vel:[ 0.08053252 -0.00406619]
#  id:atom2, pos:[3.39681292 2.45769915], vel:[-0.08053252  0.00406619]
# E: -0.08097662891250754
# avgT: 0.0
# avgP: 0.0
#
# time: 0.31
# iterations: 154
#  id:atom1, pos:[1.52334871 2.55229269], vel:[ 0.08109214 -0.00409444]
#  id:atom2, pos:[3.39665129 2.45770731], vel:[-0.08109214  0.00409444]
# E: -0.08097662871948685
# avgT: 0.0
# avgP: 0.0
#
# time: 0.31
# iterations: 155
#  id:atom1, pos:[1.52351145 2.55228447], vel:[ 0.08165241 -0.00412273]
#  id:atom2, pos:[3.39648855 2.45771553], vel:[-0.08165241  0.00412273]
# E: -0.08097662852450649
# avgT: 0.0
# avgP: 0.0
#
# time: 0.31
# iterations: 156
#  id:atom1, pos:[1.52367532 2.5522762 ], vel:[ 0.08221334 -0.00415105]
#  id:atom2, pos:[3.39632468 2.4577238 ], vel:[-0.08221334  0.00415105]
# E: -0.08097662832755036
# avgT: 0.0
# avgP: 0.0
#
# time: 0.31
# iterations: 157
#  id:atom1, pos:[1.5238403  2.55226787], vel:[ 0.08277493 -0.00417941]
#  id:atom2, pos:[3.3961597  2.45773213], vel:[-0.08277493  0.00417941]
# E: -0.08097662812860186
# avgT: 0.0
# avgP: 0.0
#
# time: 0.31
# iterations: 158
#  id:atom1, pos:[1.52400642 2.55225948], vel:[ 0.08333718 -0.0042078 ]
#  id:atom2, pos:[3.39599358 2.45774052], vel:[-0.08333718  0.0042078 ]
# E: -0.08097662792764422
# avgT: 0.0
# avgP: 0.0
#
# time: 0.32
# iterations: 159
#  id:atom1, pos:[1.52417365 2.55225104], vel:[ 0.08390011 -0.00423622]
#  id:atom2, pos:[3.39582635 2.45774896], vel:[-0.08390011  0.00423622]
# E: -0.08097662772466054
# avgT: 0.0
# avgP: 0.0
#
# time: 0.32
# iterations: 160
#  id:atom1, pos:[1.52434202 2.55224254], vel:[ 0.08446371 -0.00426468]
#  id:atom2, pos:[3.39565798 2.45775746], vel:[-0.08446371  0.00426468]
# E: -0.08097662751963387
# avgT: 0.0
# avgP: 0.0
#
# time: 0.32
# iterations: 161
#  id:atom1, pos:[1.52451151 2.55223398], vel:[ 0.085028   -0.00429317]
#  id:atom2, pos:[3.39548849 2.45776602], vel:[-0.085028    0.00429317]
# E: -0.08097662731254682
# avgT: 0.0
# avgP: 0.0
#
# time: 0.32
# iterations: 162
#  id:atom1, pos:[1.52468213 2.55222536], vel:[ 0.08559298 -0.0043217 ]
#  id:atom2, pos:[3.39531787 2.45777464], vel:[-0.08559298  0.0043217 ]
# E: -0.08097662710338184
# avgT: 0.0
# avgP: 0.0
#
# time: 0.32
# iterations: 163
#  id:atom1, pos:[1.52485388 2.55221669], vel:[ 0.08615865 -0.00435026]
#  id:atom2, pos:[3.39514612 2.45778331], vel:[-0.08615865  0.00435026]
# E: -0.08097662689212123
# avgT: 0.0
# avgP: 0.0
#
# time: 0.33
# iterations: 164
#  id:atom1, pos:[1.52502676 2.55220796], vel:[ 0.08672502 -0.00437885]
#  id:atom2, pos:[3.39497324 2.45779204], vel:[-0.08672502  0.00437885]
# E: -0.08097662667874697
# avgT: 0.0
# avgP: 0.0
#
# time: 0.33
# iterations: 165
#  id:atom1, pos:[1.52520078 2.55219918], vel:[ 0.08729209 -0.00440749]
#  id:atom2, pos:[3.39479922 2.45780082], vel:[-0.08729209  0.00440749]
# E: -0.08097662646324089
# avgT: 0.0
# avgP: 0.0
#
# time: 0.33
# iterations: 166
#  id:atom1, pos:[1.52537593 2.55219033], vel:[ 0.08785988 -0.00443615]
#  id:atom2, pos:[3.39462407 2.45780967], vel:[-0.08785988  0.00443615]
# E: -0.08097662624558442
# avgT: 0.0
# avgP: 0.0
#
# time: 0.33
# iterations: 167
#  id:atom1, pos:[1.52555222 2.55218143], vel:[ 0.08842838 -0.00446486]
#  id:atom2, pos:[3.39444778 2.45781857], vel:[-0.08842838  0.00446486]
# E: -0.08097662602575918
# avgT: 0.0
# avgP: 0.0
#
# time: 0.33
# iterations: 168
#  id:atom1, pos:[1.52572964 2.55217247], vel:[ 0.08899761 -0.0044936 ]
#  id:atom2, pos:[3.39427036 2.45782753], vel:[-0.08899761  0.0044936 ]
# E: -0.0809766258037461
# avgT: 0.0
# avgP: 0.0
#
# time: 0.34
# iterations: 169
#  id:atom1, pos:[1.52590821 2.55216346], vel:[ 0.08956756 -0.00452238]
#  id:atom2, pos:[3.39409179 2.45783654], vel:[-0.08956756  0.00452238]
# E: -0.08097662557952619
# avgT: 0.0
# avgP: 0.0
#
# time: 0.34
# iterations: 170
#  id:atom1, pos:[1.52608791 2.55215438], vel:[ 0.09013824 -0.00455119]
#  id:atom2, pos:[3.39391209 2.45784562], vel:[-0.09013824  0.00455119]
# E: -0.08097662535307994
# avgT: 0.0
# avgP: 0.0
#
# time: 0.34
# iterations: 171
#  id:atom1, pos:[1.52626876 2.55214525], vel:[ 0.09070967 -0.00458004]
#  id:atom2, pos:[3.39373124 2.45785475], vel:[-0.09070967  0.00458004]
# E: -0.08097662512438786
# avgT: 0.0
# avgP: 0.0
#
# time: 0.34
# iterations: 172
#  id:atom1, pos:[1.52645075 2.55213606], vel:[ 0.09128184 -0.00460893]
#  id:atom2, pos:[3.39354925 2.45786394], vel:[-0.09128184  0.00460893]
# E: -0.0809766248934302
# avgT: 0.0
# avgP: 0.0
#
# time: 0.34
# iterations: 173
#  id:atom1, pos:[1.52663389 2.55212682], vel:[ 0.09185476 -0.00463786]
#  id:atom2, pos:[3.39336611 2.45787318], vel:[-0.09185476  0.00463786]
# E: -0.08097662466018674
# avgT: 0.0
# avgP: 0.0
#
# time: 0.35
# iterations: 174
#  id:atom1, pos:[1.52681817 2.55211751], vel:[ 0.09242844 -0.00466683]
#  id:atom2, pos:[3.39318183 2.45788249], vel:[-0.09242844  0.00466683]
# E: -0.08097662442463714
# avgT: 0.0
# avgP: 0.0
#
# time: 0.35
# iterations: 175
#  id:atom1, pos:[1.5270036  2.55210815], vel:[ 0.09300288 -0.00469583]
#  id:atom2, pos:[3.3929964  2.45789185], vel:[-0.09300288  0.00469583]
# E: -0.08097662418676099
# avgT: 0.0
# avgP: 0.0
#
# time: 0.35
# iterations: 176
#  id:atom1, pos:[1.52719018 2.55209873], vel:[ 0.09357809 -0.00472487]
#  id:atom2, pos:[3.39280982 2.45790127], vel:[-0.09357809  0.00472487]
# E: -0.08097662394653729
# avgT: 0.0
# avgP: 0.0
#
# time: 0.35
# iterations: 177
#  id:atom1, pos:[1.52737792 2.55208925], vel:[ 0.09415407 -0.00475396]
#  id:atom2, pos:[3.39262208 2.45791075], vel:[-0.09415407  0.00475396]
# E: -0.08097662370394504
# avgT: 0.0
# avgP: 0.0
#
# time: 0.35
# iterations: 178
#  id:atom1, pos:[1.5275668  2.55207971], vel:[ 0.09473083 -0.00478308]
#  id:atom2, pos:[3.3924332  2.45792029], vel:[-0.09473083  0.00478308]
# E: -0.0809766234589629
# avgT: 0.0
# avgP: 0.0
#
# time: 0.36
# iterations: 179
#  id:atom1, pos:[1.52775684 2.55207012], vel:[ 0.09530838 -0.00481224]
#  id:atom2, pos:[3.39224316 2.45792988], vel:[-0.09530838  0.00481224]
# E: -0.0809766232115692
# avgT: 0.0
# avgP: 0.0
#
# time: 0.36
# iterations: 180
#  id:atom1, pos:[1.52794803 2.55206046], vel:[ 0.09588672 -0.00484144]
#  id:atom2, pos:[3.39205197 2.45793954], vel:[-0.09588672  0.00484144]
# E: -0.080976622961742
# avgT: 0.0
# avgP: 0.0
#
# time: 0.36
# iterations: 181
#  id:atom1, pos:[1.52814039 2.55205075], vel:[ 0.09646586 -0.00487068]
#  id:atom2, pos:[3.39185961 2.45794925], vel:[-0.09646586  0.00487068]
# E: -0.08097662270945927
# avgT: 0.0
# avgP: 0.0
#
# time: 0.36
# iterations: 182
#  id:atom1, pos:[1.5283339  2.55204098], vel:[ 0.0970458  -0.00489996]
#  id:atom2, pos:[3.3916661  2.45795902], vel:[-0.0970458   0.00489996]
# E: -0.08097662245469835
# avgT: 0.0
# avgP: 0.0
#
# time: 0.36
# iterations: 183
#  id:atom1, pos:[1.52852857 2.55203115], vel:[ 0.09762655 -0.00492929]
#  id:atom2, pos:[3.39147143 2.45796885], vel:[-0.09762655  0.00492929]
# E: -0.08097662219743679
# avgT: 0.0
# avgP: 0.0
#
# time: 0.37
# iterations: 184
#  id:atom1, pos:[1.5287244  2.55202126], vel:[ 0.09820812 -0.00495865]
#  id:atom2, pos:[3.3912756  2.45797874], vel:[-0.09820812  0.00495865]
# E: -0.08097662193765139
# avgT: 0.0
# avgP: 0.0
#
# time: 0.37
# iterations: 185
#  id:atom1, pos:[1.5289214  2.55201132], vel:[ 0.09879051 -0.00498806]
#  id:atom2, pos:[3.3910786  2.45798868], vel:[-0.09879051  0.00498806]
# E: -0.08097662167531891
# avgT: 0.0
# avgP: 0.0
#
# time: 0.37
# iterations: 186
#  id:atom1, pos:[1.52911957 2.55200131], vel:[ 0.09937373 -0.0050175 ]
#  id:atom2, pos:[3.39088043 2.45799869], vel:[-0.09937373  0.0050175 ]
# E: -0.08097662141041582
# avgT: 0.0
# avgP: 0.0
#
# time: 0.37
# iterations: 187
#  id:atom1, pos:[1.5293189  2.55199125], vel:[ 0.09995779 -0.00504699]
#  id:atom2, pos:[3.3906811  2.45800875], vel:[-0.09995779  0.00504699]
# E: -0.08097662114291833
# avgT: 0.0
# avgP: 0.0
#
# time: 0.37
# iterations: 188
#  id:atom1, pos:[1.5295194  2.55198112], vel:[ 0.10054268 -0.00507653]
#  id:atom2, pos:[3.3904806  2.45801888], vel:[-0.10054268  0.00507653]
# E: -0.08097662087280215
# avgT: 0.0
# avgP: 0.0
#
# time: 0.38
# iterations: 189
#  id:atom1, pos:[1.52972107 2.55197094], vel:[ 0.10112843 -0.0051061 ]
#  id:atom2, pos:[3.39027893 2.45802906], vel:[-0.10112843  0.0051061 ]
# E: -0.08097662060004292
# avgT: 0.0
# avgP: 0.0
#
# time: 0.38
# iterations: 190
#  id:atom1, pos:[1.52992391 2.5519607 ], vel:[ 0.10171503 -0.00513572]
#  id:atom2, pos:[3.39007609 2.4580393 ], vel:[-0.10171503  0.00513572]
# E: -0.08097662032461571
# avgT: 0.0
# avgP: 0.0
#
# time: 0.38
# iterations: 191
#  id:atom1, pos:[1.53012793 2.5519504 ], vel:[ 0.10230248 -0.00516538]
#  id:atom2, pos:[3.38987207 2.4580496 ], vel:[-0.10230248  0.00516538]
# E: -0.08097662004649553
# avgT: 0.0
# avgP: 0.0
#
# time: 0.38
# iterations: 192
#  id:atom1, pos:[1.53033312 2.55194004], vel:[ 0.10289081 -0.00519508]
#  id:atom2, pos:[3.38966688 2.45805996], vel:[-0.10289081  0.00519508]
# E: -0.08097661976565695
# avgT: 0.0
# avgP: 0.0
#
# time: 0.38
# iterations: 193
#  id:atom1, pos:[1.53053949 2.55192962], vel:[ 0.10348    -0.00522483]
#  id:atom2, pos:[3.38946051 2.45807038], vel:[-0.10348     0.00522483]
# E: -0.08097661948207438
# avgT: 0.0
# avgP: 0.0
#
# time: 0.39
# iterations: 194
#  id:atom1, pos:[1.53074704 2.55191914], vel:[ 0.10407008 -0.00525463]
#  id:atom2, pos:[3.38925296 2.45808086], vel:[-0.10407008  0.00525463]
# E: -0.08097661919572169
# avgT: 0.0
# avgP: 0.0
#
# time: 0.39
# iterations: 195
#  id:atom1, pos:[1.53095577 2.5519086 ], vel:[ 0.10466104 -0.00528447]
#  id:atom2, pos:[3.38904423 2.4580914 ], vel:[-0.10466104  0.00528447]
# E: -0.0809766189065725
# avgT: 0.0
# avgP: 0.0
#
# time: 0.39
# iterations: 196
#  id:atom1, pos:[1.53116568 2.551898  ], vel:[ 0.10525289 -0.00531435]
#  id:atom2, pos:[3.38883432 2.458102  ], vel:[-0.10525289  0.00531435]
# E: -0.0809766186146001
# avgT: 0.0
# avgP: 0.0
#
# time: 0.39
# iterations: 197
#  id:atom1, pos:[1.53137678 2.55188734], vel:[ 0.10584565 -0.00534428]
#  id:atom2, pos:[3.38862322 2.45811266], vel:[-0.10584565  0.00534428]
# E: -0.08097661831977758
# avgT: 0.0
# avgP: 0.0
#
# time: 0.39
# iterations: 198
#  id:atom1, pos:[1.53158907 2.55187662], vel:[ 0.1064393  -0.00537425]
#  id:atom2, pos:[3.38841093 2.45812338], vel:[-0.1064393   0.00537425]
# E: -0.08097661802207744
# avgT: 0.0
# avgP: 0.0
#
# time: 0.40
# iterations: 199
#  id:atom1, pos:[1.53180254 2.55186584], vel:[ 0.10703387 -0.00540427]
#  id:atom2, pos:[3.38819746 2.45813416], vel:[-0.10703387  0.00540427]
# E: -0.08097661772147198
# avgT: 0.0
# avgP: 0.0
#
# time: 0.40
# iterations: 200
#  id:atom1, pos:[1.5320172  2.55185501], vel:[ 0.10762936 -0.00543434]
#  id:atom2, pos:[3.3879828  2.45814499], vel:[-0.10762936  0.00543434]
# E: -0.0809766174179332
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.40
# iterations: 201
#  id:atom1, pos:[1.53223306 2.55184411], vel:[ 0.10822578 -0.00546445]
#  id:atom2, pos:[3.38776694 2.45815589], vel:[-0.10822578  0.00546445]
# E: -0.08097661711143259
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.40
# iterations: 202
#  id:atom1, pos:[1.53245011 2.55183315], vel:[ 0.10882312 -0.00549461]
#  id:atom2, pos:[3.38754989 2.45816685], vel:[-0.10882312  0.00549461]
# E: -0.08097661680194157
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.40
# iterations: 203
#  id:atom1, pos:[1.53266835 2.55182213], vel:[ 0.10942141 -0.00552482]
#  id:atom2, pos:[3.38733165 2.45817787], vel:[-0.10942141  0.00552482]
# E: -0.08097661648943093
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.41
# iterations: 204
#  id:atom1, pos:[1.53288779 2.55181105], vel:[ 0.11002064 -0.00555508]
#  id:atom2, pos:[3.38711221 2.45818895], vel:[-0.11002064  0.00555508]
# E: -0.08097661617387117
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.41
# iterations: 205
#  id:atom1, pos:[1.53310843 2.55179991], vel:[ 0.11062082 -0.00558538]
#  id:atom2, pos:[3.38689157 2.45820009], vel:[-0.11062082  0.00558538]
# E: -0.08097661585523235
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.41
# iterations: 206
#  id:atom1, pos:[1.53333027 2.55178871], vel:[ 0.11122196 -0.00561574]
#  id:atom2, pos:[3.38666973 2.45821129], vel:[-0.11122196  0.00561574]
# E: -0.08097661553348434
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.41
# iterations: 207
#  id:atom1, pos:[1.53355332 2.55177745], vel:[ 0.11182407 -0.00564614]
#  id:atom2, pos:[3.38644668 2.45822255], vel:[-0.11182407  0.00564614]
# E: -0.08097661520859638
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.41
# iterations: 208
#  id:atom1, pos:[1.53377757 2.55176612], vel:[ 0.11242715 -0.00567659]
#  id:atom2, pos:[3.38622243 2.45823388], vel:[-0.11242715  0.00567659]
# E: -0.08097661488053748
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.42
# iterations: 209
#  id:atom1, pos:[1.53400303 2.55175474], vel:[ 0.11303121 -0.00570709]
#  id:atom2, pos:[3.38599697 2.45824526], vel:[-0.11303121  0.00570709]
# E: -0.08097661454927632
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.42
# iterations: 210
#  id:atom1, pos:[1.5342297  2.55174329], vel:[ 0.11363626 -0.00573764]
#  id:atom2, pos:[3.3857703  2.45825671], vel:[-0.11363626  0.00573764]
# E: -0.08097661421478092
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.42
# iterations: 211
#  id:atom1, pos:[1.53445757 2.55173179], vel:[ 0.11424231 -0.00576824]
#  id:atom2, pos:[3.38554243 2.45826821], vel:[-0.11424231  0.00576824]
# E: -0.08097661387701918
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.42
# iterations: 212
#  id:atom1, pos:[1.53468666 2.55172022], vel:[ 0.11484935 -0.00579889]
#  id:atom2, pos:[3.38531334 2.45827978], vel:[-0.11484935  0.00579889]
# E: -0.08097661353595846
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.42
# iterations: 213
#  id:atom1, pos:[1.53491697 2.55170859], vel:[ 0.11545741 -0.00582959]
#  id:atom2, pos:[3.38508303 2.45829141], vel:[-0.11545741  0.00582959]
# E: -0.08097661319156589
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.43
# iterations: 214
#  id:atom1, pos:[1.53514849 2.5516969 ], vel:[ 0.11606648 -0.00586034]
#  id:atom2, pos:[3.38485151 2.4583031 ], vel:[-0.11606648  0.00586034]
# E: -0.08097661284380778
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.43
# iterations: 215
#  id:atom1, pos:[1.53538124 2.55168515], vel:[ 0.11667657 -0.00589115]
#  id:atom2, pos:[3.38461876 2.45831485], vel:[-0.11667657  0.00589115]
# E: -0.08097661249265035
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.43
# iterations: 216
#  id:atom1, pos:[1.5356152  2.55167334], vel:[ 0.11728769 -0.005922  ]
#  id:atom2, pos:[3.3843848  2.45832666], vel:[-0.11728769  0.005922  ]
# E: -0.08097661213805925
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.43
# iterations: 217
#  id:atom1, pos:[1.53585039 2.55166146], vel:[ 0.11789985 -0.00595291]
#  id:atom2, pos:[3.38414961 2.45833854], vel:[-0.11789985  0.00595291]
# E: -0.08097661177999967
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.43
# iterations: 218
#  id:atom1, pos:[1.5360868  2.55164953], vel:[ 0.11851306 -0.00598387]
#  id:atom2, pos:[3.3839132  2.45835047], vel:[-0.11851306  0.00598387]
# E: -0.08097661141843657
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.44
# iterations: 219
#  id:atom1, pos:[1.53632444 2.55163753], vel:[ 0.11912732 -0.00601489]
#  id:atom2, pos:[3.38367556 2.45836247], vel:[-0.11912732  0.00601489]
# E: -0.08097661105333419
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.44
# iterations: 220
#  id:atom1, pos:[1.53656331 2.55162547], vel:[ 0.11974264 -0.00604595]
#  id:atom2, pos:[3.38343669 2.45837453], vel:[-0.11974264  0.00604595]
# E: -0.08097661068465635
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.44
# iterations: 221
#  id:atom1, pos:[1.53680341 2.55161334], vel:[ 0.12035902 -0.00607708]
#  id:atom2, pos:[3.38319659 2.45838666], vel:[-0.12035902  0.00607708]
# E: -0.08097661031236661
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.44
# iterations: 222
#  id:atom1, pos:[1.53704475 2.55160116], vel:[ 0.12097649 -0.00610825]
#  id:atom2, pos:[3.38295525 2.45839884], vel:[-0.12097649  0.00610825]
# E: -0.08097660993642786
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.44
# iterations: 223
#  id:atom1, pos:[1.53728732 2.55158891], vel:[ 0.12159503 -0.00613948]
#  id:atom2, pos:[3.38271268 2.45841109], vel:[-0.12159503  0.00613948]
# E: -0.08097660955680255
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.45
# iterations: 224
#  id:atom1, pos:[1.53753113 2.5515766 ], vel:[ 0.12221467 -0.00617077]
#  id:atom2, pos:[3.38246887 2.4584234 ], vel:[-0.12221467  0.00617077]
# E: -0.08097660917345281
# avgT: 0.005806805811447634
# avgP: 0.0
#
# time: 0.45
# iterations: 225
#  id:atom1, pos:[1.53777617 2.55156423], vel:[ 0.1228354  -0.00620211]
#  id:atom2, pos:[3.38222383 2.45843577], vel:[-0.1228354   0.00620211]
# E: -0.08097660878633998
# ...
# avgP: 0.0
#
# time: 1.86
# iterations: 931
#  id:atom1, pos:[1.68899808 2.54392885], vel:[-0.43571311  0.0219997 ]
#  id:atom2, pos:[3.23100192 2.46607115], vel:[ 0.43571311 -0.0219997 ]
# E: -0.08097538663336454
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.86
# iterations: 932
#  id:atom1, pos:[1.68812861 2.54397275], vel:[-0.43376602  0.02190139]
#  id:atom2, pos:[3.23187139 2.46602725], vel:[ 0.43376602 -0.02190139]
# E: -0.0809754055653645
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.86
# iterations: 933
#  id:atom1, pos:[1.68726302 2.54401645], vel:[-0.43183195  0.02180373]
#  id:atom2, pos:[3.23273698 2.46598355], vel:[ 0.43183195 -0.02180373]
# E: -0.08097542416768355
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.87
# iterations: 934
#  id:atom1, pos:[1.68640128 2.54405996], vel:[-0.42991075  0.02170673]
#  id:atom2, pos:[3.23359872 2.46594004], vel:[ 0.42991075 -0.02170673]
# E: -0.08097544244654217
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.87
# iterations: 935
#  id:atom1, pos:[1.68554337 2.54410328], vel:[-0.4280023   0.02161037]
#  id:atom2, pos:[3.23445663 2.46589672], vel:[ 0.4280023  -0.02161037]
# E: -0.08097546040805162
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.87
# iterations: 936
#  id:atom1, pos:[1.68468927 2.5441464 ], vel:[-0.42610644  0.02151464]
#  id:atom2, pos:[3.23531073 2.4658536 ], vel:[ 0.42610644 -0.02151464]
# E: -0.08097547805821245
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.87
# iterations: 937
#  id:atom1, pos:[1.68383895 2.54418934], vel:[-0.42422304  0.02141955]
#  id:atom2, pos:[3.23616105 2.46581066], vel:[ 0.42422304 -0.02141955]
# E: -0.08097549540291804
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.87
# iterations: 938
#  id:atom1, pos:[1.68299238 2.54423208], vel:[-0.42235198  0.02132508]
#  id:atom2, pos:[3.23700762 2.46576792], vel:[ 0.42235198 -0.02132508]
# E: -0.08097551244795353
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.88
# iterations: 939
#  id:atom1, pos:[1.68214954 2.54427464], vel:[-0.42049311  0.02123122]
#  id:atom2, pos:[3.23785046 2.46572536], vel:[ 0.42049311 -0.02123122]
# E: -0.08097552919899845
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.88
# iterations: 940
#  id:atom1, pos:[1.68131041 2.54431701], vel:[-0.41864631  0.02113797]
#  id:atom2, pos:[3.23868959 2.46568299], vel:[ 0.41864631 -0.02113797]
# E: -0.08097554566162735
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.88
# iterations: 941
#  id:atom1, pos:[1.68047495 2.54435919], vel:[-0.41681144  0.02104533]
#  id:atom2, pos:[3.23952505 2.46564081], vel:[ 0.41681144 -0.02104533]
# E: -0.08097556184131044
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.88
# iterations: 942
#  id:atom1, pos:[1.67964316 2.54440119], vel:[-0.41498838  0.02095328]
#  id:atom2, pos:[3.24035684 2.46559881], vel:[ 0.41498838 -0.02095328]
# E: -0.08097557774341618
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.88
# iterations: 943
#  id:atom1, pos:[1.678815 2.544443], vel:[-0.41317701  0.02086182]
#  id:atom2, pos:[3.241185 2.465557], vel:[ 0.41317701 -0.02086182]
# E: -0.08097559337321125
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.89
# iterations: 944
#  id:atom1, pos:[1.67799045 2.54448464], vel:[-0.41137719  0.02077095]
#  id:atom2, pos:[3.24200955 2.46551536], vel:[ 0.41137719 -0.02077095]
# E: -0.0809756087358626
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.89
# iterations: 945
#  id:atom1, pos:[1.67716949 2.54452609], vel:[-0.40958882  0.02068065]
#  id:atom2, pos:[3.24283051 2.46547391], vel:[ 0.40958882 -0.02068065]
# E: -0.08097562383643955
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.89
# iterations: 946
#  id:atom1, pos:[1.6763521  2.54456736], vel:[-0.40781175  0.02059092]
#  id:atom2, pos:[3.2436479  2.46543264], vel:[ 0.40781175 -0.02059092]
# E: -0.08097563867991373
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.89
# iterations: 947
#  id:atom1, pos:[1.67553824 2.54460845], vel:[-0.40604589  0.02050176]
#  id:atom2, pos:[3.24446176 2.46539155], vel:[ 0.40604589 -0.02050176]
# E: -0.08097565327116088
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.89
# iterations: 948
#  id:atom1, pos:[1.67472791 2.54464936], vel:[-0.4042911   0.02041316]
#  id:atom2, pos:[3.24527209 2.46535064], vel:[ 0.4042911  -0.02041316]
# E: -0.08097566761496405
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.90
# iterations: 949
#  id:atom1, pos:[1.67392108 2.5446901 ], vel:[-0.40254727  0.02032511]
#  id:atom2, pos:[3.24607892 2.4653099 ], vel:[ 0.40254727 -0.02032511]
# E: -0.08097568171601185
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.90
# iterations: 950
#  id:atom1, pos:[1.67311772 2.54473067], vel:[-0.40081429  0.02023761]
#  id:atom2, pos:[3.24688228 2.46526933], vel:[ 0.40081429 -0.02023761]
# E: -0.08097569557890294
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.90
# iterations: 951
#  id:atom1, pos:[1.67231782 2.54477105], vel:[-0.39909204  0.02015065]
#  id:atom2, pos:[3.24768218 2.46522895], vel:[ 0.39909204 -0.02015065]
# E: -0.08097570920814623
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.90
# iterations: 952
#  id:atom1, pos:[1.67152136 2.54481127], vel:[-0.39738041  0.02006423]
#  id:atom2, pos:[3.24847864 2.46518873], vel:[ 0.39738041 -0.02006423]
# E: -0.08097572260816188
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.90
# iterations: 953
#  id:atom1, pos:[1.6707283  2.54485131], vel:[-0.3956793   0.01997834]
#  id:atom2, pos:[3.2492717  2.46514869], vel:[ 0.3956793  -0.01997834]
# E: -0.08097573578328379
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.91
# iterations: 954
#  id:atom1, pos:[1.66993864 2.54489118], vel:[-0.39398858  0.01989297]
#  id:atom2, pos:[3.25006136 2.46510882], vel:[ 0.39398858 -0.01989297]
# E: -0.08097574873776017
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.91
# iterations: 955
#  id:atom1, pos:[1.66915235 2.54493088], vel:[-0.39230816  0.01980813]
#  id:atom2, pos:[3.25084765 2.46506912], vel:[ 0.39230816 -0.01980813]
# E: -0.08097576147575536
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.91
# iterations: 956
#  id:atom1, pos:[1.66836941 2.54497041], vel:[-0.39063792  0.01972379]
#  id:atom2, pos:[3.25163059 2.46502959], vel:[ 0.39063792 -0.01972379]
# E: -0.08097577400135214
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.91
# iterations: 957
#  id:atom1, pos:[1.6675898  2.54500978], vel:[-0.38897777  0.01963997]
#  id:atom2, pos:[3.2524102  2.46499022], vel:[ 0.38897777 -0.01963997]
# E: -0.0809757863185521
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.91
# iterations: 958
#  id:atom1, pos:[1.6668135  2.54504897], vel:[-0.3873276   0.01955665]
#  id:atom2, pos:[3.2531865  2.46495103], vel:[ 0.3873276  -0.01955665]
# E: -0.08097579843127697
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.92
# iterations: 959
#  id:atom1, pos:[1.66604049 2.545088  ], vel:[-0.3856873   0.01947383]
#  id:atom2, pos:[3.25395951 2.464912  ], vel:[ 0.3856873  -0.01947383]
# E: -0.08097581034337148
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.92
# iterations: 960
#  id:atom1, pos:[1.66527075 2.54512687], vel:[-0.38405678  0.0193915 ]
#  id:atom2, pos:[3.25472925 2.46487313], vel:[ 0.38405678 -0.0193915 ]
# E: -0.0809758220586029
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.92
# iterations: 961
#  id:atom1, pos:[1.66450426 2.54516557], vel:[-0.38243593  0.01930967]
#  id:atom2, pos:[3.25549574 2.46483443], vel:[ 0.38243593 -0.01930967]
# E: -0.08097583358066404
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.92
# iterations: 962
#  id:atom1, pos:[1.663741   2.54520411], vel:[-0.38082466  0.01922831]
#  id:atom2, pos:[3.256259   2.46479589], vel:[ 0.38082466 -0.01922831]
# E: -0.08097584491317364
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.92
# iterations: 963
#  id:atom1, pos:[1.66298096 2.54524248], vel:[-0.37922287  0.01914743]
#  id:atom2, pos:[3.25701904 2.46475752], vel:[ 0.37922287 -0.01914743]
# E: -0.08097585605967844
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.93
# iterations: 964
#  id:atom1, pos:[1.66222411 2.5452807 ], vel:[-0.37763047  0.01906703]
#  id:atom2, pos:[3.25777589 2.4647193 ], vel:[ 0.37763047 -0.01906703]
# E: -0.08097586702365397
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.93
# iterations: 965
#  id:atom1, pos:[1.66147044 2.54531875], vel:[-0.37604735  0.0189871 ]
#  id:atom2, pos:[3.25852956 2.46468125], vel:[ 0.37604735 -0.0189871 ]
# E: -0.08097587780850654
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.93
# iterations: 966
#  id:atom1, pos:[1.66071992 2.54535665], vel:[-0.37447343  0.01890763]
#  id:atom2, pos:[3.25928008 2.46464335], vel:[ 0.37447343 -0.01890763]
# E: -0.08097588841757422
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.93
# iterations: 967
#  id:atom1, pos:[1.65997254 2.54539438], vel:[-0.37290861  0.01882862]
#  id:atom2, pos:[3.26002746 2.46460562], vel:[ 0.37290861 -0.01882862]
# E: -0.08097589885412798
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.93
# iterations: 968
#  id:atom1, pos:[1.65922829 2.54543196], vel:[-0.3713528   0.01875006]
#  id:atom2, pos:[3.26077171 2.46456804], vel:[ 0.3713528  -0.01875006]
# E: -0.08097590912137331
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.94
# iterations: 969
#  id:atom1, pos:[1.65848713 2.54546938], vel:[-0.36980591  0.01867196]
#  id:atom2, pos:[3.26151287 2.46453062], vel:[ 0.36980591 -0.01867196]
# E: -0.08097591922245131
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.94
# iterations: 970
#  id:atom1, pos:[1.65774906 2.54550665], vel:[-0.36826786  0.0185943 ]
#  id:atom2, pos:[3.26225094 2.46449335], vel:[ 0.36826786 -0.0185943 ]
# E: -0.08097592916044041
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.94
# iterations: 971
#  id:atom1, pos:[1.65701406 2.54554376], vel:[-0.36673855  0.01851709]
#  id:atom2, pos:[3.26298594 2.46445624], vel:[ 0.36673855 -0.01851709]
# E: -0.0809759389383565
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.94
# iterations: 972
#  id:atom1, pos:[1.65628211 2.54558072], vel:[-0.36521789  0.01844031]
#  id:atom2, pos:[3.26371789 2.46441928], vel:[ 0.36521789 -0.01844031]
# E: -0.08097594855915605
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.94
# iterations: 973
#  id:atom1, pos:[1.65555319 2.54561752], vel:[-0.36370581  0.01836396]
#  id:atom2, pos:[3.26444681 2.46438248], vel:[ 0.36370581 -0.01836396]
# E: -0.08097595802573518
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.95
# iterations: 974
#  id:atom1, pos:[1.65482729 2.54565417], vel:[-0.36220222  0.01828804]
#  id:atom2, pos:[3.26517271 2.46434583], vel:[ 0.36220222 -0.01828804]
# E: -0.08097596734093279
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.95
# iterations: 975
#  id:atom1, pos:[1.65410438 2.54569067], vel:[-0.36070703  0.01821255]
#  id:atom2, pos:[3.26589562 2.46430933], vel:[ 0.36070703 -0.01821255]
# E: -0.0809759765075303
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.95
# iterations: 976
#  id:atom1, pos:[1.65338446 2.54572702], vel:[-0.35922016  0.01813747]
#  id:atom2, pos:[3.26661554 2.46427298], vel:[ 0.35922016 -0.01813747]
# E: -0.08097598552825333
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.95
# iterations: 977
#  id:atom1, pos:[1.6526675  2.54576322], vel:[-0.35774153  0.01806281]
#  id:atom2, pos:[3.2673325  2.46423678], vel:[ 0.35774153 -0.01806281]
# E: -0.08097599440577335
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.95
# iterations: 978
#  id:atom1, pos:[1.65195349 2.54579927], vel:[-0.35627105  0.01798857]
#  id:atom2, pos:[3.26804651 2.46420073], vel:[ 0.35627105 -0.01798857]
# E: -0.08097600314270711
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.96
# iterations: 979
#  id:atom1, pos:[1.65124242 2.54583518], vel:[-0.35480866  0.01791473]
#  id:atom2, pos:[3.26875758 2.46416482], vel:[ 0.35480866 -0.01791473]
# E: -0.08097601174162039
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.96
# iterations: 980
#  id:atom1, pos:[1.65053426 2.54587093], vel:[-0.35335427  0.0178413 ]
#  id:atom2, pos:[3.26946574 2.46412907], vel:[ 0.35335427 -0.0178413 ]
# E: -0.0809760202050265
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.96
# iterations: 981
#  id:atom1, pos:[1.649829   2.54590654], vel:[-0.3519078   0.01776826]
#  id:atom2, pos:[3.270171   2.46409346], vel:[ 0.3519078  -0.01776826]
# E: -0.08097602853538949
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.96
# iterations: 982
#  id:atom1, pos:[1.64912663 2.54594201], vel:[-0.35046917  0.01769562]
#  id:atom2, pos:[3.27087337 2.46405799], vel:[ 0.35046917 -0.01769562]
# E: -0.08097603673512287
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.96
# iterations: 983
#  id:atom1, pos:[1.64842712 2.54597732], vel:[-0.34903832  0.01762338]
#  id:atom2, pos:[3.27157288 2.46402268], vel:[ 0.34903832 -0.01762338]
# E: -0.08097604480659278
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.97
# iterations: 984
#  id:atom1, pos:[1.64773047 2.5460125 ], vel:[-0.34761516  0.01755152]
#  id:atom2, pos:[3.27226953 2.4639875 ], vel:[ 0.34761516 -0.01755152]
# E: -0.08097605275211778
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.97
# iterations: 985
#  id:atom1, pos:[1.64703666 2.54604753], vel:[-0.34619962  0.01748005]
#  id:atom2, pos:[3.27296334 2.46395247], vel:[ 0.34619962 -0.01748005]
# E: -0.08097606057397035
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.97
# iterations: 986
#  id:atom1, pos:[1.64634567 2.54608242], vel:[-0.34479164  0.01740896]
#  id:atom2, pos:[3.27365433 2.46391758], vel:[ 0.34479164 -0.01740896]
# E: -0.08097606827437764
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.97
# iterations: 987
#  id:atom1, pos:[1.6456575  2.54611717], vel:[-0.34339112  0.01733825]
#  id:atom2, pos:[3.2743425  2.46388283], vel:[ 0.34339112 -0.01733825]
# E: -0.08097607585552202
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.97
# iterations: 988
#  id:atom1, pos:[1.64497211 2.54615177], vel:[-0.34199802  0.01726791]
#  id:atom2, pos:[3.27502789 2.46384823], vel:[ 0.34199802 -0.01726791]
# E: -0.08097608331954304
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.98
# iterations: 989
#  id:atom1, pos:[1.6442895  2.54618624], vel:[-0.34061225  0.01719794]
#  id:atom2, pos:[3.2757105  2.46381376], vel:[ 0.34061225 -0.01719794]
# E: -0.08097609066853727
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.98
# iterations: 990
#  id:atom1, pos:[1.64360966 2.54622056], vel:[-0.33923374  0.01712833]
#  id:atom2, pos:[3.27639034 2.46377944], vel:[ 0.33923374 -0.01712833]
# E: -0.08097609790455958
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.98
# iterations: 991
#  id:atom1, pos:[1.64293257 2.54625475], vel:[-0.33786243  0.01705909]
#  id:atom2, pos:[3.27706743 2.46374525], vel:[ 0.33786243 -0.01705909]
# E: -0.08097610502962453
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.98
# iterations: 992
#  id:atom1, pos:[1.64225821 2.5462888 ], vel:[-0.33649825  0.01699022]
#  id:atom2, pos:[3.27774179 2.4637112 ], vel:[ 0.33649825 -0.01699022]
# E: -0.08097611204570647
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.98
# iterations: 993
#  id:atom1, pos:[1.64158658 2.54632271], vel:[-0.33514112  0.01692169]
#  id:atom2, pos:[3.27841342 2.46367729], vel:[ 0.33514112 -0.01692169]
# E: -0.08097611895474034
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.99
# iterations: 994
#  id:atom1, pos:[1.64091765 2.54635649], vel:[-0.333791    0.01685352]
#  id:atom2, pos:[3.27908235 2.46364351], vel:[ 0.333791   -0.01685352]
# E: -0.08097612575862337
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.99
# iterations: 995
#  id:atom1, pos:[1.64025141 2.54639013], vel:[-0.3324478  0.0167857]
#  id:atom2, pos:[3.27974859 2.46360987], vel:[ 0.3324478 -0.0167857]
# E: -0.08097613245921477
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.99
# iterations: 996
#  id:atom1, pos:[1.63958786 2.54642363], vel:[-0.33111147  0.01671823]
#  id:atom2, pos:[3.28041214 2.46357637], vel:[ 0.33111147 -0.01671823]
# E: -0.08097613905833764
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.99
# iterations: 997
#  id:atom1, pos:[1.63892697 2.546457  ], vel:[-0.32978194  0.0166511 ]
#  id:atom2, pos:[3.28107303 2.463543  ], vel:[ 0.32978194 -0.0166511 ]
# E: -0.08097614555777863
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 1.99
# iterations: 998
#  id:atom1, pos:[1.63826873 2.54649023], vel:[-0.32845914  0.01658431]
#  id:atom2, pos:[3.28173127 2.46350977], vel:[ 0.32845914 -0.01658431]
# E: -0.08097615195928981
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 2.00
# iterations: 999
#  id:atom1, pos:[1.63761313 2.54652334], vel:[-0.32714302  0.01651786]
#  id:atom2, pos:[3.28238687 2.46347666], vel:[ 0.32714302 -0.01651786]
# E: -0.08097615826458832
# avgT: 0.15367584994048072
# avgP: 0.0
#
# time: 2.00
# iterations: 1000
#  id:atom1, pos:[1.63696016 2.54655631], vel:[-0.32583352  0.01645174]
#  id:atom2, pos:[3.28303984 2.46344369], vel:[ 0.32583352 -0.01645174]
# E: -0.08097616447535767
# avgT: 0.13358449395231975
# avgP: 0.0
#
# 0.782935380935669 seconds elapsed
